# %% [markdown]
# # Sample 2 - Use Catagory Predict

# %% [markdown]
# ### Problem Statement
#
# sample นี้จะใช้ข้อมูลที่กลุ่มประเภท​ (Catagory,Object) มาทดสอบว่าสามารถคาดเดาราคาของที่พักได้หรือไม่

# %% [markdown]
# # Import Package

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
plt.style.use("ggplot")
import json
import missingno as msno

from sklearn import linear_model
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.dummy import DummyRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, RidgeCV, Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

from fastai import *
from fastai.tabular import *
from fastai.test_utils import *

# %% [markdown]
# # Import Data

# %%
df_district = pd.read_csv('Meterial/bangkok_district.csv')
df_train = pd.read_json('Meterial/train.json')
df_test = pd.read_json('Meterial/test.json')

# %%
print(df_train.shape)
print(df_district.shape)
print(df_test.shape)
# Out:
# (14271, 23)
# (331, 6)
# (2500, 22)

# %%
# Data Train to predict price
df_train.keys()
# Out:
# Index(['id', 'province', 'district', 'subdistrict', 'address', 'property_type',
#        'total_units', 'bedrooms', 'baths', 'floor_area', 'floor_level',
#        'land_area', 'latitude', 'longitude', 'nearby_stations',
#        'nearby_station_distance', 'nearby_bus_stops', 'nearby_supermarkets',
#        'nearby_shops', 'year_built', 'month_built', 'facilities', 'price'],
#       dtype='object')

# %%
# Data Test need to predict Price
df_test.keys()
# Out:
# Index(['id', 'province', 'district', 'subdistrict', 'address', 'property_type',
#        'total_units', 'bedrooms', 'baths', 'floor_area', 'floor_level',
#        'land_area', 'latitude', 'longitude', 'nearby_stations',
#        'nearby_station_distance', 'nearby_bus_stops', 'nearby_supermarkets',
#        'nearby_shops', 'year_built', 'month_built', 'facilities'],
#       dtype='object')

# %%
df_train.describe()
# Out:
#                  id   total_units      bedrooms         baths    floor_area  \
# count  1.427100e+04  10509.000000  14228.000000  14236.000000  14271.000000
# mean   1.062614e+07    712.655438      1.880728      1.618292     79.867283
# std    8.030103e+05    554.558340      1.092817      0.872875     69.701181
# min    1.025114e+06      1.000000      1.000000      0.000000      1.000000
# 25%    1.064588e+07    318.000000      1.000000      1.000000     32.000000
# 50%    1.086984e+07    554.000000      1.000000      1.000000     47.000000
# 75%    1.097710e+07    945.000000      3.000000      2.000000    112.000000
# max    1.104790e+07   4000.000000     10.000000      9.000000    766.000000
#
#        floor_level      land_area      latitude     longitude  \
# count  8093.000000    4917.000000  14271.000000  14271.000000
# mean     11.322995     242.963596     13.762814    100.565017
# std       9.064835    3083.223006      0.092787      0.089575
# min       1.000000      16.000000     13.517062    100.273931
# 25%       4.000000      80.000000     13.705177    100.512628
# 50%       8.000000     116.000000     13.753742    100.569721
# 75%      17.000000     212.000000     13.837514    100.608786
# max      55.000000  137664.000000     14.022246    100.905485
#
#        nearby_stations  nearby_bus_stops  nearby_supermarkets  nearby_shops  \
# count     14271.000000       6009.000000         13885.000000  14271.000000
# mean          0.956415         14.049426             9.002161     10.447060
# std           1.085255          6.496828             5.348001      6.950903
# min           0.000000          1.000000             1.000000      1.000000
# 25%           0.000000          8.000000             5.000000      4.000000
# 50%           1.000000         17.000000             8.000000      9.000000
# 75%           2.000000         20.000000            13.000000     19.000000
# max           3.000000         20.000000            20.000000     20.000000
#
#          year_built         price
# count  14271.000000  1.427100e+04
# mean    1422.737440  4.044124e+06
# std      917.737592  2.179909e+06
# min        0.000000  4.800000e+05
# 25%        0.000000  2.250000e+06
# 50%     2013.000000  3.500000e+06
# 75%     2017.000000  5.500000e+06
# max     2023.000000  9.999000e+06

# %%
df_test.describe()
# Out:
#                  id  total_units     bedrooms        baths   floor_area  \
# count  2.500000e+03  1858.000000  2490.000000  2490.000000  2500.000000
# mean   1.063709e+07   713.160388     1.848193     1.601205    77.423200
# std    7.743160e+05   577.473009     1.081384     0.854877    66.966167
# min    1.755218e+06     1.000000     1.000000     0.000000    17.000000
# 25%    1.066092e+07   306.000000     1.000000     1.000000    31.000000
# 50%    1.087636e+07   539.000000     1.000000     1.000000    46.000000
# 75%    1.098185e+07   954.000000     3.000000     2.000000   110.000000
# max    1.104783e+07  4000.000000    10.000000     6.000000   564.000000
#
#        floor_level    land_area     latitude    longitude  nearby_stations  \
# count  1401.000000   841.000000  2500.000000  2500.000000      2500.000000
# mean     11.233405   151.491082    13.762411   100.564914         0.946400
# std       8.885489   132.335460     0.092938     0.091116         1.069946
# min       1.000000    20.000000    13.521062   100.052922         0.000000
# 25%       4.000000    80.000000    13.704274   100.514235         0.000000
# 50%       8.000000   112.000000    13.754998   100.571334         1.000000
# 75%      17.000000   204.000000    13.838146   100.608291         2.000000
# max      49.000000  2516.000000    14.095025   100.892813         3.000000
#
#        nearby_bus_stops  nearby_supermarkets  nearby_shops   year_built
# count       1026.000000          2414.000000   2500.000000  2500.000000
# mean          14.254386             9.140431     10.494400  1433.655600
# std            6.551753             5.439392      6.955208   912.882062
# min            1.000000             1.000000      1.000000     0.000000
# 25%            8.000000             5.000000      4.000000     0.000000
# 50%           17.000000             8.000000      9.000000  2013.000000
# 75%           20.000000            13.000000     20.000000  2017.000000
# max           20.000000            20.000000     20.000000  2023.000000

# %% [markdown]
# # EDA (Train & Test)

# %% [markdown]
# ### Data Train

# %%
data_train = df_train[['province', 'district', 'subdistrict','property_type','total_units','bedrooms','baths','floor_area','floor_level','nearby_supermarkets','nearby_shops','price']]
data_train["num_facility"] = df_train["facilities"].apply(len)

data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14271 entries, 0 to 14270
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   province             14271 non-null  object
#  1   district             14271 non-null  object
#  2   subdistrict          14260 non-null  object
#  3   property_type        14271 non-null  object
#  4   total_units          10509 non-null  float64
#  5   bedrooms             14228 non-null  float64
#  6   baths                14236 non-null  float64
#  7   floor_area           14271 non-null  int64
#  8   floor_level          8093 non-null   float64
#  9   nearby_supermarkets  13885 non-null  float64
#  10  nearby_shops         14271 non-null  int64
#  11  price                14271 non-null  int64
#  12  num_facility         14271 non-null  int64
# dtypes: float64(5), int64(4), object(4)
# memory usage: 1.4+ MB
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/2666788323.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train["num_facility"] = df_train["facilities"].apply(len)

# %% [markdown]
# ### Data Test

# %%
# Data to test

data_test = df_test[['id','province', 'district', 'subdistrict','property_type','total_units','bedrooms','baths','floor_area','floor_level','nearby_supermarkets','nearby_shops']]
data_test["num_facility"] = df_train["facilities"].apply(len)

data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2500 non-null   int64
#  1   province             2500 non-null   object
#  2   district             2500 non-null   object
#  3   subdistrict          2497 non-null   object
#  4   property_type        2500 non-null   object
#  5   total_units          1858 non-null   float64
#  6   bedrooms             2490 non-null   float64
#  7   baths                2490 non-null   float64
#  8   floor_area           2500 non-null   int64
#  9   floor_level          1401 non-null   float64
#  10  nearby_supermarkets  2414 non-null   float64
#  11  nearby_shops         2500 non-null   int64
#  12  num_facility         2500 non-null   int64
# dtypes: float64(5), int64(4), object(4)
# memory usage: 254.0+ KB
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1944823157.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test["num_facility"] = df_train["facilities"].apply(len)

# %% [markdown]
# ### Replace missing value by Mean in each catagory

# %%
data_train['total_units'].fillna(data_train.groupby(["property_type"])["total_units"].transform('mean'), inplace = True)
data_test['total_units'].fillna(data_test.groupby(["property_type"])["total_units"].transform('mean'), inplace = True)

data_train['bedrooms'].fillna(data_train.groupby(["property_type"])["bedrooms"].transform('mean'), inplace = True)
data_test['bedrooms'].fillna(data_test.groupby(["property_type"])["bedrooms"].transform('mean'), inplace = True)

data_train['baths'].fillna(data_train.groupby(["property_type"])["baths"].transform('mean'), inplace = True)
data_test['baths'].fillna(data_test.groupby(["property_type"])["baths"].transform('mean'), inplace = True)

data_train['floor_level'].fillna(data_train.groupby(["property_type"])["floor_level"].transform('mean'), inplace = True)
data_test['floor_level'].fillna(data_test.groupby(["property_type"])["floor_level"].transform('mean'), inplace = True)

data_train['nearby_supermarkets'].fillna(data_train.groupby(["property_type"])["nearby_supermarkets"].transform('mean'), inplace = True)
data_test['nearby_supermarkets'].fillna(data_test.groupby(["property_type"])["nearby_supermarkets"].transform('mean'), inplace = True)
# Out:
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1637906010.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['total_units'].fillna(data_train.groupby(["property_type"])["total_units"].transform('mean'), inplace = True)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1637906010.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['total_units'].fillna(data_test.groupby(["property_type"])["total_units"].transform('mean'), inplace = True)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1637906010.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['bedrooms'].fillna(data_train.groupby(["property_type"])["bedrooms"].transform('mean'), inplace = True)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1637906010.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['bedrooms'].fillna(data_test.groupby(["property_type"])["bedrooms"].transform('mean'), inplace = True)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1637906010.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['baths'].fillna(data_train.groupby(["property_type"])["baths"].transform('mean'), inplace = True)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1637906010.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['baths'].fillna(data_test.groupby(["property_type"])["baths"].transform('mean'), inplace = True)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1637906010.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['floor_level'].fillna(data_train.groupby(["property_type"])["floor_level"].transform('mean'), inplace = True)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1637906010.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['floor_level'].fillna(data_test.groupby(["property_type"])["floor_level"].transform('mean'), inplace = True)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1637906010.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['nearby_supermarkets'].fillna(data_train.groupby(["property_type"])["nearby_supermarkets"].transform('mean'), inplace = True)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1637906010.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['nearby_supermarkets'].fillna(data_test.groupby(["property_type"])["nearby_supermarkets"].transform('mean'), inplace = True)

# %% [markdown]
# ### Another Solution to replace NaN by using KNNImputer

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5) 

# แทนค่า total_units ที่ว่าง
data_train['imputed_column'] = imputer.fit_transform(data_train[['total_units']])
data_test['imputed_column'] = imputer.fit_transform(data_test[['total_units']])

# total_units - แทนที่ field จริงด้วย dummy ที่ gen ขึ้นมา
data_train['total_units'] = data_train['imputed_column']
data_train.drop(columns=['imputed_column'], inplace=True)

data_test['total_units'] = data_test['imputed_column']
data_test.drop(columns=['imputed_column'], inplace=True)

# %% [markdown]
# ### Create Function to Flag Facility & Station

# %%
# Function find Near station and distanct !! if no station = NaN
def closest_station(station_list, return_value='station_name'):
    if type(station_list) != list:
        if return_value == 'station_name':
            return "NO STATION"
        elif return_value == 'station_distance':
            return np.nan
    else:
        if return_value == 'station_name':
            return station_list[0][0]
        elif return_value == 'station_distance':
            return station_list[0][1]

#data_train['distance'] = data_train.apply(distance, axis=1)
#data_train['closest_station_name'] = df_train.nearby_station_distance.apply(lambda x: closest_station(x, 'station_name'))
data_train['closest_station_distance'] = df_train.nearby_station_distance.apply(lambda x: closest_station(x, 'station_distance'))
data_test['closest_station_distance'] = df_test.nearby_station_distance.apply(lambda x: closest_station(x, 'station_distance'))
# Out:
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1932124695.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['closest_station_distance'] = df_train.nearby_station_distance.apply(lambda x: closest_station(x, 'station_distance'))
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/1932124695.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['closest_station_distance'] = df_test.nearby_station_distance.apply(lambda x: closest_station(x, 'station_distance'))

# %% [markdown]
# ##### Replace close station with mean in each property_type

# %%
data_train['closest_station_distance'].fillna(data_train.groupby(["property_type"])["closest_station_distance"].transform('mean'), inplace = True)
data_test['closest_station_distance'].fillna(data_test.groupby(["property_type"])["closest_station_distance"].transform('mean'), inplace = True)
# Out:
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/980912694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['closest_station_distance'].fillna(data_train.groupby(["property_type"])["closest_station_distance"].transform('mean'), inplace = True)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/980912694.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['closest_station_distance'].fillna(data_test.groupby(["property_type"])["closest_station_distance"].transform('mean'), inplace = True)

# %%
# Function Create Flag if selet field have value > 0 Then 1 Else 0
def flag_by_value (value):
    if value > 0:
        return 1
    else:
        return 0

# %%
# Apply the function to the entire DataFrame
data_train['flag_facility'] = data_train['num_facility'].apply(flag_by_value)
data_train['flag_station'] = data_train['closest_station_distance'].apply(flag_by_value)

data_test['flag_facility'] = data_test['num_facility'].apply(flag_by_value)
data_test['flag_station'] = data_test['closest_station_distance'].apply(flag_by_value)
# Out:
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/2146967705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['flag_facility'] = data_train['num_facility'].apply(flag_by_value)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/2146967705.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train['flag_station'] = data_train['closest_station_distance'].apply(flag_by_value)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/2146967705.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['flag_facility'] = data_test['num_facility'].apply(flag_by_value)
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/2146967705.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['flag_station'] = data_test['closest_station_distance'].apply(flag_by_value)

# %% [markdown]
# ### Check Data again after cleansing

# %%
#Check Null Value
msno.matrix(data_train, figsize=(15,2),fontsize=8,labels="Data Train") ;
#plt.legend(['missing','not missing'], bbox_to_anchor=(1, 0.5))
msno.matrix(data_test, figsize=(15,2),fontsize=8,labels="Data Predict") ;
gray_patch = mpatches.Patch(color='gray', label='Data present')
white_patch = mpatches.Patch(color='white', label='Data absent ')
plt.legend(handles=[gray_patch, white_patch])

# %% [markdown]
# #### Decare total data type

# %%
## หาจำนวนของแต่ละ Data Type : Data Train
obj = (data_train.dtypes == 'object')
object_cols = list(obj[obj].index)
print("Data Train")
print("Categorical variables:",len(object_cols))
 
int_ = (data_train.dtypes == 'int')
num_cols = list(int_[int_].index)
print("Integer variables:",len(num_cols))
 
fl = (data_train.dtypes == 'float')
fl_cols = list(fl[fl].index)
print("Float variables:",len(fl_cols))
# Out:
# Data Train
# Categorical variables: 4
# Integer variables: 6
# Float variables: 6

# %%
## หาจำนวนของแต่ละ Data Type : Data Test
obj = (data_test.dtypes == 'object')
object_cols = list(obj[obj].index)
print("Data Test")
print("Categorical variables:",len(object_cols))
 
int_ = (data_test.dtypes == 'int')
num_cols = list(int_[int_].index)
print("Integer variables:",len(num_cols))
 
fl = (data_test.dtypes == 'float')
fl_cols = list(fl[fl].index)
print("Float variables:",len(fl_cols))
# Out:
# Data Test
# Categorical variables: 4
# Integer variables: 6
# Float variables: 6

# %% [markdown]
# #### Check total of data

# %%
unique_values = []
for col in object_cols:
  unique_values.append(data_train[col].unique().size)
plt.figure(figsize=(5,2))
plt.title('No. Unique values of Categorical Features')
plt.xticks(rotation=90)
sns.barplot(x=object_cols,y=unique_values)
# Out:
# <Axes: title={'center': 'No. Unique values of Categorical Features'}>

# %%
plt.figure(figsize=(10, 10))
plt.title('Categorical Features: Distribution')
plt.xticks(rotation=90)
index = 1
 
for col in object_cols:
    y = data_train[col].value_counts()
    plt.subplot(2, 2, index)
    plt.xticks(rotation=90)
    sns.barplot(x=list(y.index), y=y)
    index += 1
# Out:
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from current font.
#   func(*args, **kwargs)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from current font.
#   func(*args, **kwargs)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 3639 (\N{THAI CHARACTER SARA UEE}) missing from current font.
#   func(*args, **kwargs)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from current font.
#   func(*args, **kwargs)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from current font.
#   func(*args, **kwargs)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 3607 (\N{THAI CHARACTER THO THAHAN}) missing from current font.
#   func(*args, **kwargs)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 3608 (\N{THAI CHARACTER THO THONG}) missing from current font.
#   func(*args, **kwargs)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from current font.
#   func(*args, **kwargs)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from current font.
#   func(*args, **kwargs)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from current font.
#   func(*args, **kwargs)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 3639 (\N{THAI CHARACTER SARA UEE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 3607 (\N{THAI CHARACTER THO THAHAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 3608 (\N{THAI CHARACTER THO THONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 3637 (\N{THAI CHARACTER SARA II}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Drop Column subdistrict

# %%
data_train.drop(['subdistrict'], #subdistrict
             axis=1,
             inplace=True)

data_test.drop(['subdistrict'],
             axis=1,
             inplace=True)
# Out:
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/2859036198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train.drop(['subdistrict'], #subdistrict
# /var/folders/mf/6mt5qmss0f96q77c2c1530ch0000gn/T/ipykernel_6953/2859036198.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test.drop(['subdistrict'],

# %%
# Show Feature = Categorical
print("Data Train : Categorical")
s = (data_train.dtypes == 'object')
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print('No. of. categorical features: ', 
      len(object_cols))


print("Data Test : Categorical")
s = (data_test.dtypes == 'object')
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print('No. of. categorical features: ', 
      len(object_cols))
# Out:
# Data Train : Categorical
# Categorical variables:
# ['province', 'district', 'property_type']
# No. of. categorical features:  3
# Data Test : Categorical
# Categorical variables:
# ['province', 'district', 'property_type']
# No. of. categorical features:  3

# %% [markdown]
# #### Create Dummy for Classification

# %%
OH_encoder = OneHotEncoder(sparse=False)
OH_cols = pd.DataFrame(OH_encoder.fit_transform(data_train[object_cols]))
OH_cols.index = data_train.index
OH_cols.columns = OH_encoder.get_feature_names_out()
df_final_train = data_train.drop(object_cols, axis=1)
df_final_train = pd.concat([df_final_train, OH_cols], axis=1)

OH_encoder = OneHotEncoder(sparse=False)
OH_cols = pd.DataFrame(OH_encoder.fit_transform(data_test[object_cols]))
OH_cols.index = data_test.index
OH_cols.columns = OH_encoder.get_feature_names_out()
df_final_test = data_test.drop(object_cols, axis=1)
df_final_test = pd.concat([df_final_test, OH_cols], axis=1)
# Out:
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Create Data for Training and Testing

# %%
# Final Data Train : 
X = df_final_train.drop(['price'], axis=1)
Y = df_final_train['price']
 
# Split the training set into 
# training and validation set
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, train_size=0.8, test_size=0.2, random_state=0)

# %% [markdown]
# # Model and Accuracy
# SVM-Support Vector Machine \
# Random Forest Regressor \
# Linear Regressor

# %% [markdown]
# ## Model 1 - SVM

# %%
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import mean_absolute_percentage_error
 
model_SVR = svm.SVR()
model_SVR.fit(X_train,Y_train)
Y_pred_SVR = model_SVR.predict(X_test)
 
print(mean_absolute_percentage_error(Y_test, Y_pred_SVR))
# Out:
# 0.5343127696234882

# %% [markdown]
# ### Model 1 - Result

# %%
# เทียบระหว่าง y_test กับ y_predict
# Mean Absolute Error (MAE)
mae_test = mean_absolute_error(Y_test, Y_pred_SVR)
print("Mean absolute error: %.3f" % mae_test)
# Mean Square Error
mse_test=mean_squared_error(Y_test, Y_pred_SVR)
print("Mean squared error: %.3f" % mse_test)

# R2-score: Explained variance (coefficient of determination) score: 1 is perfect prediction

r2_test= r2_score(Y_test, Y_pred_SVR)
print('R2-score: %.3f' % r2_test)
# Out:
# Mean absolute error: 1790854.351
# Mean squared error: 5098265953762.881
# R2-score: -0.065

# %% [markdown]
# ## Model 2 - Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
 
model_RFR = RandomForestRegressor(n_estimators=10)
model_RFR.fit(X_train, Y_train)
Y_pred_RFR = model_RFR.predict(X_test)
 
mean_absolute_percentage_error(Y_test, Y_pred_RFR)
# Out:
# 0.16607368092556737

# %% [markdown]
# ### Model 2 - Result

# %%
# เทียบระหว่าง y_test กับ y_predict
# Mean Absolute Error (MAE)
mae_test = mean_absolute_error(Y_test, Y_pred_RFR)
print("Mean absolute error: %.3f" % mae_test)
# Mean Square Error
mse_test=mean_squared_error(Y_test, Y_pred_RFR)
print("Mean squared error: %.3f" % mse_test)

# R2-score: Explained variance (coefficient of determination) score: 1 is perfect prediction

r2_test= r2_score(Y_test, Y_pred_RFR)
print('R2-score: %.3f' % r2_test)
# Out:
# Mean absolute error: 630263.483
# Mean squared error: 915481463076.208
# R2-score: 0.809

# %% [markdown]
# ## Model 3 - Linear Regression

# %%
from sklearn.linear_model import LinearRegression
 
model_LR = LinearRegression()
model_LR.fit(X_train, Y_train)
Y_pred_LR = model_LR.predict(X_test)
 
print(mean_absolute_percentage_error(Y_test, Y_pred_LR))
# Out:
# 0.2706170401110578

# %% [markdown]
# ### Model 3 - Result

# %%
# เทียบระหว่าง y_test กับ y_predict
# Mean Absolute Error (MAE)
mae_test = mean_absolute_error(Y_test, Y_pred_LR)
print("Mean absolute error: %.3f" % mae_test)
# Mean Square Error
mse_test=mean_squared_error(Y_test, Y_pred_LR)
print("Mean squared error: %.3f" % mse_test)

# R2-score: Explained variance (coefficient of determination) score: 1 is perfect prediction

r2_test= r2_score(Y_test, Y_pred_LR)
print('R2-score: %.3f' % r2_test)
# Out:
# Mean absolute error: 948664.971
# Mean squared error: 1606639657829.542
# R2-score: 0.664

# %%
from yellowbrick.datasets import load_concrete
from yellowbrick.regressor import PredictionError
from yellowbrick.style import set_palette

set_palette('accent')
model = LinearRegression()
visualizer = PredictionError(model)

visualizer.fit(X_train, Y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, Y_test)  # Evaluate the model on the test data
visualizer.show()
# Out:
# <Axes: title={'center': 'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %% [markdown]
# ## Model 4 - Catboots Regression

# %%
from catboost import CatBoostRegressor
cb_model = CatBoostRegressor()
cb_model.fit(X_train, Y_train)
preds_cb = cb_model.predict(X_test) 
 
cb_r2_score=r2_score(Y_test, preds_cb)
cb_r2_score
# Out:
# Learning rate set to 0.060154
# 0:	learn: 2112419.1385292	total: 2.13ms	remaining: 2.13s
# 1:	learn: 2049954.9964797	total: 4.25ms	remaining: 2.12s
# 2:	learn: 1994307.9541927	total: 6.25ms	remaining: 2.08s
# 3:	learn: 1942801.3025622	total: 7.83ms	remaining: 1.95s
# 4:	learn: 1891615.8011331	total: 9.52ms	remaining: 1.9s
# 5:	learn: 1846167.2038064	total: 11ms	remaining: 1.83s
# 6:	learn: 1802594.3494846	total: 12.9ms	remaining: 1.83s
# 7:	learn: 1763164.0230978	total: 14.4ms	remaining: 1.79s
# 8:	learn: 1729754.5556888	total: 15.9ms	remaining: 1.75s
# 9:	learn: 1694728.5287814	total: 17.5ms	remaining: 1.73s
# 10:	learn: 1664181.6352589	total: 18.9ms	remaining: 1.7s
# 11:	learn: 1634814.5330384	total: 20.5ms	remaining: 1.69s
# 12:	learn: 1609002.0619030	total: 22ms	remaining: 1.67s
# 13:	learn: 1581836.1584075	total: 23.5ms	remaining: 1.65s
# 14:	learn: 1557572.1398865	total: 25ms	remaining: 1.64s
# 15:	learn: 1537198.8164978	total: 26.5ms	remaining: 1.63s
# 16:	learn: 1515863.9641862	total: 28ms	remaining: 1.62s
# 17:	learn: 1497677.5718172	total: 29.4ms	remaining: 1.6s
# 18:	learn: 1479163.2488911	total: 30.8ms	remaining: 1.59s
# 19:	learn: 1461284.6920412	total: 32.2ms	remaining: 1.57s
# 20:	learn: 1444936.6485812	total: 33.5ms	remaining: 1.56s
# 21:	learn: 1429909.7178215	total: 35.1ms	remaining: 1.56s
# 22:	learn: 1415237.8678976	total: 36.6ms	remaining: 1.55s
# 23:	learn: 1400936.8430044	total: 37.8ms	remaining: 1.54s
# 24:	learn: 1388805.2666494	total: 39ms	remaining: 1.52s
# 25:	learn: 1377473.7690925	total: 40.3ms	remaining: 1.51s
# 26:	learn: 1365811.2234829	total: 41.4ms	remaining: 1.49s
# 27:	learn: 1355253.6300817	total: 42.6ms	remaining: 1.48s
# 28:	learn: 1343666.0909964	total: 44.1ms	remaining: 1.48s
# 29:	learn: 1333406.4361546	total: 45.4ms	remaining: 1.47s
# 30:	learn: 1324780.5107841	total: 46.8ms	remaining: 1.46s
# 31:	learn: 1317296.9072725	total: 48.2ms	remaining: 1.46s
# 32:	learn: 1308831.2527419	total: 49.4ms	remaining: 1.45s
# 33:	learn: 1301008.6233839	total: 50.7ms	remaining: 1.44s
# 34:	learn: 1293689.7064496	total: 52ms	remaining: 1.43s
# 35:	learn: 1286917.5646615	total: 53.2ms	remaining: 1.42s
# 36:	learn: 1279922.0904017	total: 54.5ms	remaining: 1.42s
# 37:	learn: 1273818.0948929	total: 56.1ms	remaining: 1.42s
# 38:	learn: 1268381.6329237	total: 57.6ms	remaining: 1.42s
# 39:	learn: 1262738.4393210	total: 58.8ms	remaining: 1.41s
# 40:	learn: 1257718.7323151	total: 60.1ms	remaining: 1.41s
# 41:	learn: 1252428.8435193	total: 61.3ms	remaining: 1.4s
# 42:	learn: 1247529.7577713	total: 62.6ms	remaining: 1.39s
# 43:	learn: 1242654.1535308	total: 63.9ms	remaining: 1.39s
# 44:	learn: 1238360.8895136	total: 65.2ms	remaining: 1.38s
# 45:	learn: 1234297.0426262	total: 66.5ms	remaining: 1.38s
# 46:	learn: 1230038.3912530	total: 67.7ms	remaining: 1.37s
# 47:	learn: 1225822.1222540	total: 68.9ms	remaining: 1.36s
# 48:	learn: 1222272.2728769	total: 70.1ms	remaining: 1.36s
# 49:	learn: 1218973.0970815	total: 71.4ms	remaining: 1.36s
# 50:	learn: 1215587.0235060	total: 72.5ms	remaining: 1.35s
# 51:	learn: 1212315.7256816	total: 73.6ms	remaining: 1.34s
# 52:	learn: 1209037.7221719	total: 74.9ms	remaining: 1.34s
# 53:	learn: 1205466.1030741	total: 76.4ms	remaining: 1.34s
# 54:	learn: 1202574.8368493	total: 77.6ms	remaining: 1.33s
# 55:	learn: 1199964.3490984	total: 78.8ms	remaining: 1.33s
# 56:	learn: 1196813.3992259	total: 80.4ms	remaining: 1.33s
# 57:	learn: 1193869.6712130	total: 81.6ms	remaining: 1.32s
# 58:	learn: 1191392.9892164	total: 83.1ms	remaining: 1.32s
# 59:	learn: 1189360.6368510	total: 84.3ms	remaining: 1.32s
# 60:	learn: 1186330.8532923	total: 85.5ms	remaining: 1.32s
# 61:	learn: 1183801.3359554	total: 86.8ms	remaining: 1.31s
# 62:	learn: 1181847.7973637	total: 88ms	remaining: 1.31s
# 63:	learn: 1179807.9859433	total: 90.1ms	remaining: 1.32s
# 64:	learn: 1177481.0929811	total: 91.3ms	remaining: 1.31s
# 65:	learn: 1174910.8350197	total: 92.6ms	remaining: 1.31s
# 66:	learn: 1173126.4432748	total: 93.8ms	remaining: 1.31s
# 67:	learn: 1170698.0026426	total: 95.5ms	remaining: 1.31s
# 68:	learn: 1168528.4500900	total: 96.9ms	remaining: 1.31s
# 69:	learn: 1165896.3582913	total: 98.3ms	remaining: 1.3s
# 70:	learn: 1164140.7518678	total: 99.4ms	remaining: 1.3s
# 71:	learn: 1162552.8534047	total: 101ms	remaining: 1.3s
# 72:	learn: 1160834.8302280	total: 102ms	remaining: 1.29s
# 73:	learn: 1158586.5669996	total: 103ms	remaining: 1.29s
# 74:	learn: 1156837.2789750	total: 105ms	remaining: 1.29s
# 75:	learn: 1154967.6264626	total: 106ms	remaining: 1.29s
# 76:	learn: 1153195.6970357	total: 108ms	remaining: 1.29s
# 77:	learn: 1151450.0294984	total: 109ms	remaining: 1.29s
# 78:	learn: 1149659.0757566	total: 110ms	remaining: 1.29s
# 79:	learn: 1148370.4709226	total: 112ms	remaining: 1.28s
# 80:	learn: 1146590.9984002	total: 113ms	remaining: 1.28s
# 81:	learn: 1145297.0842329	total: 114ms	remaining: 1.28s
# 82:	learn: 1143837.7883503	total: 115ms	remaining: 1.27s
# 83:	learn: 1142427.7436386	total: 117ms	remaining: 1.27s
# 84:	learn: 1140660.0781936	total: 118ms	remaining: 1.27s
# 85:	learn: 1139089.8262514	total: 120ms	remaining: 1.27s
# 86:	learn: 1137241.3695114	total: 121ms	remaining: 1.27s
# 87:	learn: 1135961.3363505	total: 123ms	remaining: 1.27s
# 88:	learn: 1134236.1559009	total: 124ms	remaining: 1.27s
# 89:	learn: 1132810.7972050	total: 126ms	remaining: 1.27s
# 90:	learn: 1131298.7736172	total: 127ms	remaining: 1.27s
# 91:	learn: 1130205.6758744	total: 128ms	remaining: 1.26s
# 92:	learn: 1129013.4504448	total: 130ms	remaining: 1.27s
# 93:	learn: 1127617.2486218	total: 132ms	remaining: 1.27s
# 94:	learn: 1126449.0966044	total: 133ms	remaining: 1.26s
# 95:	learn: 1124985.6503935	total: 134ms	remaining: 1.26s
# 96:	learn: 1123603.0237675	total: 136ms	remaining: 1.26s
# 97:	learn: 1122307.6828222	total: 137ms	remaining: 1.26s
# 98:	learn: 1121103.6432707	total: 138ms	remaining: 1.26s
# 99:	learn: 1119719.9750450	total: 140ms	remaining: 1.26s
# 100:	learn: 1118783.9782841	total: 141ms	remaining: 1.25s
# 101:	learn: 1117226.4302584	total: 142ms	remaining: 1.25s
# 102:	learn: 1116075.8953136	total: 144ms	remaining: 1.25s
# 103:	learn: 1114914.4851570	total: 145ms	remaining: 1.25s
# 104:	learn: 1113763.3052399	total: 146ms	remaining: 1.25s
# 105:	learn: 1112005.5383458	total: 147ms	remaining: 1.24s
# 106:	learn: 1111073.4370397	total: 149ms	remaining: 1.24s
# 107:	learn: 1110299.5730364	total: 150ms	remaining: 1.24s
# 108:	learn: 1108837.6224824	total: 151ms	remaining: 1.24s
# 109:	learn: 1107836.5763926	total: 153ms	remaining: 1.23s
# 110:	learn: 1107130.6481648	total: 154ms	remaining: 1.23s
# 111:	learn: 1106384.8335768	total: 155ms	remaining: 1.23s
# 112:	learn: 1105486.3742386	total: 156ms	remaining: 1.23s
# 113:	learn: 1104760.4467371	total: 158ms	remaining: 1.22s
# 114:	learn: 1103409.0221825	total: 159ms	remaining: 1.22s
# 115:	learn: 1102361.4316426	total: 160ms	remaining: 1.22s
# 116:	learn: 1101073.5348734	total: 162ms	remaining: 1.22s
# 117:	learn: 1099924.4937898	total: 163ms	remaining: 1.22s
# 118:	learn: 1099134.6155762	total: 164ms	remaining: 1.22s
# 119:	learn: 1097981.6613231	total: 166ms	remaining: 1.21s
# 120:	learn: 1096728.9898115	total: 167ms	remaining: 1.21s
# 121:	learn: 1096030.4963471	total: 168ms	remaining: 1.21s
# 122:	learn: 1095029.1905491	total: 169ms	remaining: 1.21s
# 123:	learn: 1094518.4110755	total: 171ms	remaining: 1.21s
# 124:	learn: 1093402.1729018	total: 172ms	remaining: 1.2s
# 125:	learn: 1092380.7488838	total: 173ms	remaining: 1.2s
# 126:	learn: 1090728.5867382	total: 175ms	remaining: 1.2s
# 127:	learn: 1090018.2982601	total: 176ms	remaining: 1.2s
# 128:	learn: 1088847.0082848	total: 178ms	remaining: 1.2s
# 129:	learn: 1088233.3651546	total: 179ms	remaining: 1.2s
# 130:	learn: 1087309.2781177	total: 180ms	remaining: 1.19s
# 131:	learn: 1086535.7614101	total: 181ms	remaining: 1.19s
# 132:	learn: 1085847.1926061	total: 183ms	remaining: 1.19s
# 133:	learn: 1084830.6410299	total: 184ms	remaining: 1.19s
# 134:	learn: 1083988.5234236	total: 185ms	remaining: 1.19s
# 135:	learn: 1083126.1546106	total: 187ms	remaining: 1.19s
# 136:	learn: 1082341.2104143	total: 188ms	remaining: 1.18s
# 137:	learn: 1081814.9377671	total: 189ms	remaining: 1.18s
# 138:	learn: 1080622.7088766	total: 191ms	remaining: 1.18s
# 139:	learn: 1079832.1981377	total: 192ms	remaining: 1.18s
# 140:	learn: 1077862.6232265	total: 194ms	remaining: 1.18s
# 141:	learn: 1077330.2159554	total: 195ms	remaining: 1.18s
# 142:	learn: 1076758.5667557	total: 197ms	remaining: 1.18s
# 143:	learn: 1075784.1270981	total: 198ms	remaining: 1.18s
# 144:	learn: 1074570.3803955	total: 199ms	remaining: 1.18s
# 145:	learn: 1073974.5423125	total: 201ms	remaining: 1.17s
# 146:	learn: 1072576.2313247	total: 202ms	remaining: 1.17s
# 147:	learn: 1071744.6199854	total: 203ms	remaining: 1.17s
# 148:	learn: 1071070.4939132	total: 205ms	remaining: 1.17s
# 149:	learn: 1069284.3824498	total: 206ms	remaining: 1.17s
# 150:	learn: 1068183.4241792	total: 207ms	remaining: 1.17s
# 151:	learn: 1067125.2991462	total: 209ms	remaining: 1.16s
# 152:	learn: 1066475.6987725	total: 211ms	remaining: 1.17s
# 153:	learn: 1065769.8962770	total: 212ms	remaining: 1.16s
# 154:	learn: 1065193.4626659	total: 213ms	remaining: 1.16s
# 155:	learn: 1064219.7245809	total: 215ms	remaining: 1.16s
# 156:	learn: 1063351.8443108	total: 216ms	remaining: 1.16s
# 157:	learn: 1062726.2359055	total: 217ms	remaining: 1.16s
# 158:	learn: 1061549.3228327	total: 218ms	remaining: 1.15s
# 159:	learn: 1060821.6132100	total: 219ms	remaining: 1.15s
# 160:	learn: 1060362.1773817	total: 221ms	remaining: 1.15s
# 161:	learn: 1059950.9349419	total: 222ms	remaining: 1.15s
# 162:	learn: 1059213.6889118	total: 223ms	remaining: 1.14s
# 163:	learn: 1058601.9647899	total: 224ms	remaining: 1.14s
# 164:	learn: 1056771.0523177	total: 225ms	remaining: 1.14s
# 165:	learn: 1055852.8462924	total: 227ms	remaining: 1.14s
# 166:	learn: 1054702.4986671	total: 228ms	remaining: 1.14s
# 167:	learn: 1053756.2851505	total: 229ms	remaining: 1.13s
# 168:	learn: 1053129.2654995	total: 230ms	remaining: 1.13s
# 169:	learn: 1052235.1859601	total: 231ms	remaining: 1.13s
# 170:	learn: 1051627.8046614	total: 232ms	remaining: 1.13s
# 171:	learn: 1050886.1571486	total: 234ms	remaining: 1.13s
# 172:	learn: 1050354.0011863	total: 235ms	remaining: 1.12s
# 173:	learn: 1049269.3001854	total: 236ms	remaining: 1.12s
# 174:	learn: 1048514.3357404	total: 237ms	remaining: 1.12s
# 175:	learn: 1047712.4847107	total: 239ms	remaining: 1.12s
# 176:	learn: 1046902.1227694	total: 240ms	remaining: 1.11s
# 177:	learn: 1046022.7166353	total: 241ms	remaining: 1.11s
# 178:	learn: 1045010.8257160	total: 242ms	remaining: 1.11s
# 179:	learn: 1044172.3447688	total: 243ms	remaining: 1.11s
# 180:	learn: 1043078.7625716	total: 244ms	remaining: 1.1s
# 181:	learn: 1042086.6385928	total: 246ms	remaining: 1.1s
# 182:	learn: 1040982.1355210	total: 247ms	remaining: 1.1s
# 183:	learn: 1039873.0087973	total: 248ms	remaining: 1.1s
# 184:	learn: 1039326.7637403	total: 249ms	remaining: 1.1s
# 185:	learn: 1037760.9342618	total: 251ms	remaining: 1.1s
# 186:	learn: 1037155.2681457	total: 252ms	remaining: 1.09s
# 187:	learn: 1036097.2846680	total: 253ms	remaining: 1.09s
# 188:	learn: 1035234.4676272	total: 254ms	remaining: 1.09s
# 189:	learn: 1034551.5568091	total: 255ms	remaining: 1.09s
# 190:	learn: 1033667.9232378	total: 256ms	remaining: 1.08s
# 191:	learn: 1032949.5666177	total: 258ms	remaining: 1.08s
# 192:	learn: 1032246.8898108	total: 259ms	remaining: 1.08s
# 193:	learn: 1031531.4609505	total: 260ms	remaining: 1.08s
# 194:	learn: 1030850.6804750	total: 261ms	remaining: 1.08s
# 195:	learn: 1029457.9673945	total: 262ms	remaining: 1.08s
# 196:	learn: 1028857.2038509	total: 263ms	remaining: 1.07s
# 197:	learn: 1028033.0330561	total: 265ms	remaining: 1.07s
# 198:	learn: 1027338.0300613	total: 266ms	remaining: 1.07s
# 199:	learn: 1026568.5290292	total: 267ms	remaining: 1.07s
# 200:	learn: 1025828.3317143	total: 268ms	remaining: 1.06s
# 201:	learn: 1025235.8981091	total: 269ms	remaining: 1.06s
# 202:	learn: 1024145.2130395	total: 270ms	remaining: 1.06s
# 203:	learn: 1023028.9144483	total: 271ms	remaining: 1.06s
# 204:	learn: 1022415.2114628	total: 273ms	remaining: 1.06s
# 205:	learn: 1021713.5400594	total: 274ms	remaining: 1.05s
# 206:	learn: 1020787.3773651	total: 275ms	remaining: 1.05s
# 207:	learn: 1019971.7626277	total: 276ms	remaining: 1.05s
# 208:	learn: 1019086.6191223	total: 277ms	remaining: 1.05s
# 209:	learn: 1018276.2248944	total: 279ms	remaining: 1.05s
# 210:	learn: 1017420.1324764	total: 280ms	remaining: 1.04s
# 211:	learn: 1016727.1418562	total: 281ms	remaining: 1.04s
# 212:	learn: 1015992.2716941	total: 282ms	remaining: 1.04s
# 213:	learn: 1015506.9724688	total: 283ms	remaining: 1.04s
# 214:	learn: 1014894.0800170	total: 284ms	remaining: 1.04s
# 215:	learn: 1014281.7134218	total: 285ms	remaining: 1.03s
# 216:	learn: 1013487.1992999	total: 287ms	remaining: 1.03s
# 217:	learn: 1012813.2780144	total: 288ms	remaining: 1.03s
# 218:	learn: 1012374.9558279	total: 289ms	remaining: 1.03s
# 219:	learn: 1011232.9417141	total: 290ms	remaining: 1.03s
# 220:	learn: 1010761.8955108	total: 291ms	remaining: 1.03s
# 221:	learn: 1010042.6771522	total: 292ms	remaining: 1.02s
# 222:	learn: 1009272.6420395	total: 293ms	remaining: 1.02s
# 223:	learn: 1008790.5294651	total: 295ms	remaining: 1.02s
# 224:	learn: 1008218.0253955	total: 296ms	remaining: 1.02s
# 225:	learn: 1007367.9539548	total: 297ms	remaining: 1.01s
# 226:	learn: 1006828.4231659	total: 298ms	remaining: 1.01s
# 227:	learn: 1005995.7836879	total: 299ms	remaining: 1.01s
# 228:	learn: 1005238.9819880	total: 300ms	remaining: 1.01s
# 229:	learn: 1004730.9894633	total: 301ms	remaining: 1.01s
# 230:	learn: 1004077.8973659	total: 302ms	remaining: 1s
# 231:	learn: 1003405.4178684	total: 303ms	remaining: 1s
# 232:	learn: 1002623.5494016	total: 304ms	remaining: 1s
# 233:	learn: 1002003.6209559	total: 306ms	remaining: 1s
# 234:	learn: 1001392.7280338	total: 307ms	remaining: 999ms
# 235:	learn: 1000993.8786066	total: 308ms	remaining: 997ms
# 236:	learn: 1000580.0187545	total: 309ms	remaining: 995ms
# 237:	learn: 1000017.8516120	total: 310ms	remaining: 993ms
# 238:	learn: 999274.5681571	total: 312ms	remaining: 992ms
# 239:	learn: 998629.7205228	total: 313ms	remaining: 990ms
# 240:	learn: 998253.4374893	total: 314ms	remaining: 988ms
# 241:	learn: 997707.2923655	total: 316ms	remaining: 988ms
# 242:	learn: 997300.3778527	total: 317ms	remaining: 986ms
# 243:	learn: 996844.6622441	total: 318ms	remaining: 985ms
# 244:	learn: 996104.9936404	total: 319ms	remaining: 983ms
# 245:	learn: 995592.6331753	total: 320ms	remaining: 981ms
# 246:	learn: 995057.0470461	total: 321ms	remaining: 979ms
# 247:	learn: 994264.1200341	total: 322ms	remaining: 978ms
# 248:	learn: 993771.5824868	total: 324ms	remaining: 976ms
# 249:	learn: 993202.7570130	total: 325ms	remaining: 974ms
# 250:	learn: 992554.2169205	total: 326ms	remaining: 972ms
# 251:	learn: 992092.2790365	total: 327ms	remaining: 970ms
# 252:	learn: 991459.0386172	total: 328ms	remaining: 969ms
# 253:	learn: 990862.5090458	total: 329ms	remaining: 967ms
# 254:	learn: 990071.3323438	total: 330ms	remaining: 965ms
# 255:	learn: 989606.8863604	total: 332ms	remaining: 964ms
# 256:	learn: 988972.5797193	total: 333ms	remaining: 962ms
# 257:	learn: 988311.5069329	total: 334ms	remaining: 961ms
# 258:	learn: 987624.5338700	total: 336ms	remaining: 960ms
# 259:	learn: 987200.5531535	total: 337ms	remaining: 958ms
# 260:	learn: 986737.4474655	total: 338ms	remaining: 957ms
# 261:	learn: 986204.5939102	total: 339ms	remaining: 956ms
# 262:	learn: 985723.7299302	total: 341ms	remaining: 954ms
# 263:	learn: 984966.5263579	total: 342ms	remaining: 953ms
# 264:	learn: 984422.6432859	total: 343ms	remaining: 952ms
# 265:	learn: 983805.2534544	total: 344ms	remaining: 950ms
# 266:	learn: 983347.8320802	total: 345ms	remaining: 948ms
# 267:	learn: 982786.5243470	total: 347ms	remaining: 947ms
# 268:	learn: 982184.1529351	total: 348ms	remaining: 945ms
# 269:	learn: 981867.7046201	total: 349ms	remaining: 943ms
# 270:	learn: 981276.2219903	total: 350ms	remaining: 942ms
# 271:	learn: 980727.1843556	total: 351ms	remaining: 940ms
# 272:	learn: 980349.9774807	total: 352ms	remaining: 938ms
# 273:	learn: 979600.4420049	total: 353ms	remaining: 937ms
# 274:	learn: 979122.1608520	total: 355ms	remaining: 935ms
# 275:	learn: 978800.9641022	total: 356ms	remaining: 933ms
# 276:	learn: 977986.5510576	total: 357ms	remaining: 931ms
# 277:	learn: 977427.8241371	total: 358ms	remaining: 930ms
# 278:	learn: 976825.6741812	total: 359ms	remaining: 928ms
# 279:	learn: 976290.2926716	total: 360ms	remaining: 926ms
# 280:	learn: 975797.3240560	total: 362ms	remaining: 926ms
# 281:	learn: 975089.3801717	total: 363ms	remaining: 924ms
# 282:	learn: 974383.6283663	total: 364ms	remaining: 923ms
# 283:	learn: 973796.0928468	total: 366ms	remaining: 922ms
# 284:	learn: 973507.8400156	total: 367ms	remaining: 920ms
# 285:	learn: 972963.1820637	total: 368ms	remaining: 918ms
# 286:	learn: 972219.2380396	total: 369ms	remaining: 917ms
# 287:	learn: 971746.2274900	total: 370ms	remaining: 915ms
# 288:	learn: 971249.1990164	total: 371ms	remaining: 913ms
# 289:	learn: 970758.1372593	total: 372ms	remaining: 912ms
# 290:	learn: 969805.8131505	total: 374ms	remaining: 910ms
# 291:	learn: 969244.2093597	total: 375ms	remaining: 909ms
# 292:	learn: 968620.4678258	total: 376ms	remaining: 907ms
# 293:	learn: 968126.8743896	total: 377ms	remaining: 905ms
# 294:	learn: 967618.3468923	total: 378ms	remaining: 904ms
# 295:	learn: 966988.2654002	total: 380ms	remaining: 903ms
# 296:	learn: 966209.2276912	total: 381ms	remaining: 901ms
# 297:	learn: 965814.0394669	total: 382ms	remaining: 900ms
# 298:	learn: 965353.9321022	total: 383ms	remaining: 899ms
# 299:	learn: 965060.3517576	total: 384ms	remaining: 897ms
# 300:	learn: 964465.9681412	total: 386ms	remaining: 896ms
# 301:	learn: 963870.4190993	total: 387ms	remaining: 895ms
# 302:	learn: 963498.4915085	total: 388ms	remaining: 894ms
# 303:	learn: 962881.7477720	total: 390ms	remaining: 892ms
# 304:	learn: 962226.7084483	total: 391ms	remaining: 890ms
# 305:	learn: 961674.7426048	total: 392ms	remaining: 889ms
# 306:	learn: 961218.1084965	total: 393ms	remaining: 888ms
# 307:	learn: 960731.0166958	total: 395ms	remaining: 886ms
# 308:	learn: 960322.8665400	total: 396ms	remaining: 885ms
# 309:	learn: 960002.2439340	total: 397ms	remaining: 883ms
# 310:	learn: 959415.1921175	total: 398ms	remaining: 882ms
# 311:	learn: 958855.3978571	total: 400ms	remaining: 881ms
# 312:	learn: 958163.8535793	total: 401ms	remaining: 880ms
# 313:	learn: 957564.0667499	total: 402ms	remaining: 879ms
# 314:	learn: 957060.0441725	total: 404ms	remaining: 878ms
# 315:	learn: 956766.5016180	total: 405ms	remaining: 877ms
# 316:	learn: 956121.2738817	total: 407ms	remaining: 876ms
# 317:	learn: 955740.1754271	total: 408ms	remaining: 874ms
# 318:	learn: 955074.2056482	total: 409ms	remaining: 873ms
# 319:	learn: 954540.2942840	total: 410ms	remaining: 871ms
# 320:	learn: 954041.8166087	total: 411ms	remaining: 870ms
# 321:	learn: 953501.0819768	total: 412ms	remaining: 868ms
# 322:	learn: 952711.9112048	total: 413ms	remaining: 867ms
# 323:	learn: 952195.9686860	total: 415ms	remaining: 865ms
# 324:	learn: 951662.9155098	total: 416ms	remaining: 864ms
# 325:	learn: 951073.4339713	total: 417ms	remaining: 862ms
# 326:	learn: 950552.1291356	total: 418ms	remaining: 861ms
# 327:	learn: 950317.4125957	total: 419ms	remaining: 859ms
# 328:	learn: 949770.5050241	total: 420ms	remaining: 858ms
# 329:	learn: 949434.0728359	total: 422ms	remaining: 856ms
# 330:	learn: 948965.4975521	total: 423ms	remaining: 855ms
# 331:	learn: 948461.0187466	total: 424ms	remaining: 853ms
# 332:	learn: 947881.2602336	total: 425ms	remaining: 852ms
# 333:	learn: 947435.9897922	total: 426ms	remaining: 850ms
# 334:	learn: 947162.6948242	total: 428ms	remaining: 849ms
# 335:	learn: 946835.2212855	total: 429ms	remaining: 847ms
# 336:	learn: 946139.4028949	total: 430ms	remaining: 846ms
# 337:	learn: 945667.4338943	total: 431ms	remaining: 845ms
# 338:	learn: 945177.8595107	total: 433ms	remaining: 844ms
# 339:	learn: 944560.4974947	total: 434ms	remaining: 843ms
# 340:	learn: 944212.2206264	total: 435ms	remaining: 841ms
# 341:	learn: 943645.3176564	total: 436ms	remaining: 840ms
# 342:	learn: 943309.6958276	total: 438ms	remaining: 838ms
# 343:	learn: 942876.1949705	total: 439ms	remaining: 837ms
# 344:	learn: 942332.7139098	total: 440ms	remaining: 835ms
# 345:	learn: 941878.0095719	total: 442ms	remaining: 835ms
# 346:	learn: 941400.3850409	total: 443ms	remaining: 833ms
# 347:	learn: 940615.4127880	total: 444ms	remaining: 833ms
# 348:	learn: 940207.5396909	total: 446ms	remaining: 831ms
# 349:	learn: 939760.5048880	total: 448ms	remaining: 831ms
# 350:	learn: 939301.2799042	total: 449ms	remaining: 830ms
# 351:	learn: 938843.7988967	total: 450ms	remaining: 828ms
# 352:	learn: 938366.8488755	total: 451ms	remaining: 827ms
# 353:	learn: 938044.9554205	total: 452ms	remaining: 825ms
# 354:	learn: 937834.0802521	total: 454ms	remaining: 824ms
# 355:	learn: 937236.2355468	total: 455ms	remaining: 823ms
# 356:	learn: 936821.1676993	total: 456ms	remaining: 821ms
# 357:	learn: 936341.7438034	total: 457ms	remaining: 820ms
# 358:	learn: 936000.3800920	total: 458ms	remaining: 818ms
# 359:	learn: 935200.6182533	total: 459ms	remaining: 817ms
# 360:	learn: 934662.5304018	total: 461ms	remaining: 815ms
# 361:	learn: 934379.3892785	total: 462ms	remaining: 814ms
# 362:	learn: 933755.3025178	total: 463ms	remaining: 813ms
# 363:	learn: 933342.4185890	total: 464ms	remaining: 811ms
# 364:	learn: 932761.8676789	total: 465ms	remaining: 810ms
# 365:	learn: 932506.7734370	total: 466ms	remaining: 808ms
# 366:	learn: 931981.3402467	total: 468ms	remaining: 807ms
# 367:	learn: 931710.9118865	total: 469ms	remaining: 805ms
# 368:	learn: 931461.1361152	total: 470ms	remaining: 804ms
# 369:	learn: 930817.2965037	total: 471ms	remaining: 802ms
# 370:	learn: 930364.1574270	total: 472ms	remaining: 800ms
# 371:	learn: 929917.5214520	total: 473ms	remaining: 799ms
# 372:	learn: 929507.0721816	total: 474ms	remaining: 797ms
# 373:	learn: 929158.9659374	total: 475ms	remaining: 796ms
# 374:	learn: 928651.7637986	total: 477ms	remaining: 794ms
# 375:	learn: 928229.8104905	total: 478ms	remaining: 793ms
# 376:	learn: 927750.4486953	total: 479ms	remaining: 791ms
# 377:	learn: 927260.3454770	total: 480ms	remaining: 790ms
# 378:	learn: 926736.2837864	total: 481ms	remaining: 788ms
# 379:	learn: 926244.1106523	total: 482ms	remaining: 787ms
# 380:	learn: 925754.7141769	total: 483ms	remaining: 785ms
# 381:	learn: 925259.2436351	total: 484ms	remaining: 784ms
# 382:	learn: 924831.6273618	total: 486ms	remaining: 782ms
# 383:	learn: 924539.8812274	total: 487ms	remaining: 781ms
# 384:	learn: 924237.7629771	total: 488ms	remaining: 779ms
# 385:	learn: 923707.2888348	total: 489ms	remaining: 778ms
# 386:	learn: 923242.3763729	total: 490ms	remaining: 776ms
# 387:	learn: 922800.8101496	total: 491ms	remaining: 775ms
# 388:	learn: 922473.5478666	total: 492ms	remaining: 773ms
# 389:	learn: 921981.4364509	total: 493ms	remaining: 772ms
# 390:	learn: 921634.3939967	total: 494ms	remaining: 770ms
# 391:	learn: 921363.4205023	total: 495ms	remaining: 768ms
# 392:	learn: 921084.8352630	total: 496ms	remaining: 767ms
# 393:	learn: 920685.9244929	total: 497ms	remaining: 765ms
# 394:	learn: 920243.8286512	total: 499ms	remaining: 764ms
# 395:	learn: 919845.6701244	total: 500ms	remaining: 762ms
# 396:	learn: 919265.2961514	total: 501ms	remaining: 761ms
# 397:	learn: 918789.3766865	total: 502ms	remaining: 759ms
# 398:	learn: 918379.3538743	total: 503ms	remaining: 757ms
# 399:	learn: 917946.1044737	total: 504ms	remaining: 756ms
# 400:	learn: 917478.4581132	total: 505ms	remaining: 755ms
# 401:	learn: 917187.8777571	total: 506ms	remaining: 753ms
# 402:	learn: 916480.7502057	total: 507ms	remaining: 751ms
# 403:	learn: 916122.5040203	total: 508ms	remaining: 750ms
# 404:	learn: 915772.4041539	total: 509ms	remaining: 748ms
# 405:	learn: 915336.8222845	total: 510ms	remaining: 747ms
# 406:	learn: 915096.9443979	total: 511ms	remaining: 745ms
# 407:	learn: 914709.4636808	total: 513ms	remaining: 744ms
# 408:	learn: 914427.8583513	total: 514ms	remaining: 742ms
# 409:	learn: 913939.5717301	total: 515ms	remaining: 741ms
# 410:	learn: 913575.4031826	total: 516ms	remaining: 739ms
# 411:	learn: 913252.7983394	total: 517ms	remaining: 738ms
# 412:	learn: 912919.7195039	total: 518ms	remaining: 736ms
# 413:	learn: 912630.1258838	total: 519ms	remaining: 735ms
# 414:	learn: 912199.6708761	total: 520ms	remaining: 733ms
# 415:	learn: 911683.5026879	total: 521ms	remaining: 732ms
# 416:	learn: 911435.5778443	total: 522ms	remaining: 730ms
# 417:	learn: 911229.6140406	total: 523ms	remaining: 729ms
# 418:	learn: 910725.3206064	total: 524ms	remaining: 727ms
# 419:	learn: 910404.5892797	total: 526ms	remaining: 726ms
# 420:	learn: 909739.6864811	total: 527ms	remaining: 724ms
# 421:	learn: 909289.1487989	total: 528ms	remaining: 723ms
# 422:	learn: 908983.9241954	total: 529ms	remaining: 721ms
# 423:	learn: 908784.6391151	total: 530ms	remaining: 720ms
# 424:	learn: 908469.5467339	total: 531ms	remaining: 718ms
# 425:	learn: 908130.3061983	total: 532ms	remaining: 717ms
# 426:	learn: 907822.7809678	total: 533ms	remaining: 715ms
# 427:	learn: 907237.4994247	total: 534ms	remaining: 714ms
# 428:	learn: 906700.0609906	total: 535ms	remaining: 713ms
# 429:	learn: 906232.2477393	total: 536ms	remaining: 711ms
# 430:	learn: 905962.9848892	total: 538ms	remaining: 710ms
# 431:	learn: 905597.4975984	total: 539ms	remaining: 708ms
# 432:	learn: 905377.8337035	total: 540ms	remaining: 707ms
# 433:	learn: 904629.4107549	total: 541ms	remaining: 705ms
# 434:	learn: 904156.0395785	total: 542ms	remaining: 704ms
# 435:	learn: 903800.8929157	total: 543ms	remaining: 702ms
# 436:	learn: 903183.4765871	total: 544ms	remaining: 701ms
# 437:	learn: 902735.7225352	total: 545ms	remaining: 699ms
# 438:	learn: 902333.7205604	total: 546ms	remaining: 698ms
# 439:	learn: 902036.7484973	total: 547ms	remaining: 696ms
# 440:	learn: 901398.0726437	total: 548ms	remaining: 695ms
# 441:	learn: 901065.8345871	total: 549ms	remaining: 694ms
# 442:	learn: 900748.7924162	total: 550ms	remaining: 692ms
# 443:	learn: 900458.4362624	total: 551ms	remaining: 691ms
# 444:	learn: 900169.5690339	total: 553ms	remaining: 689ms
# 445:	learn: 899790.2631461	total: 554ms	remaining: 688ms
# 446:	learn: 899586.4776369	total: 555ms	remaining: 686ms
# 447:	learn: 899331.8497419	total: 556ms	remaining: 685ms
# 448:	learn: 898777.0207676	total: 557ms	remaining: 683ms
# 449:	learn: 898460.2773437	total: 558ms	remaining: 682ms
# 450:	learn: 898025.7230745	total: 559ms	remaining: 681ms
# 451:	learn: 897565.2962254	total: 560ms	remaining: 679ms
# 452:	learn: 897111.9798626	total: 561ms	remaining: 678ms
# 453:	learn: 896810.0946854	total: 562ms	remaining: 676ms
# 454:	learn: 896386.8611752	total: 563ms	remaining: 675ms
# 455:	learn: 895812.5330304	total: 564ms	remaining: 673ms
# 456:	learn: 895529.8367591	total: 566ms	remaining: 672ms
# 457:	learn: 895168.8460931	total: 567ms	remaining: 671ms
# 458:	learn: 894706.7133275	total: 568ms	remaining: 669ms
# 459:	learn: 894330.7909810	total: 569ms	remaining: 668ms
# 460:	learn: 893969.0099362	total: 570ms	remaining: 666ms
# 461:	learn: 893717.7486335	total: 571ms	remaining: 665ms
# 462:	learn: 893522.6101065	total: 572ms	remaining: 663ms
# 463:	learn: 893184.4717153	total: 573ms	remaining: 662ms
# 464:	learn: 892601.1558148	total: 574ms	remaining: 661ms
# 465:	learn: 892115.5573738	total: 575ms	remaining: 659ms
# 466:	learn: 891703.0122460	total: 576ms	remaining: 658ms
# 467:	learn: 891437.3624747	total: 578ms	remaining: 657ms
# 468:	learn: 891120.8485538	total: 579ms	remaining: 655ms
# 469:	learn: 890802.6011507	total: 580ms	remaining: 654ms
# 470:	learn: 890651.3778251	total: 581ms	remaining: 652ms
# 471:	learn: 890247.4909696	total: 582ms	remaining: 651ms
# 472:	learn: 889869.5290246	total: 583ms	remaining: 649ms
# 473:	learn: 889620.2991841	total: 584ms	remaining: 648ms
# 474:	learn: 889350.1700802	total: 585ms	remaining: 647ms
# 475:	learn: 888966.5937224	total: 586ms	remaining: 645ms
# 476:	learn: 888630.1643898	total: 587ms	remaining: 644ms
# 477:	learn: 888318.5030377	total: 588ms	remaining: 643ms
# 478:	learn: 888079.0441164	total: 590ms	remaining: 641ms
# 479:	learn: 887760.3356952	total: 591ms	remaining: 640ms
# 480:	learn: 887521.5303647	total: 592ms	remaining: 639ms
# 481:	learn: 887158.0744482	total: 593ms	remaining: 637ms
# 482:	learn: 886857.6459766	total: 594ms	remaining: 636ms
# 483:	learn: 886569.5535547	total: 595ms	remaining: 635ms
# 484:	learn: 886251.5193137	total: 596ms	remaining: 633ms
# 485:	learn: 885551.4662546	total: 597ms	remaining: 632ms
# 486:	learn: 885150.3679152	total: 599ms	remaining: 630ms
# 487:	learn: 884865.5586507	total: 600ms	remaining: 629ms
# 488:	learn: 884465.8301701	total: 601ms	remaining: 628ms
# 489:	learn: 883891.7088445	total: 602ms	remaining: 626ms
# 490:	learn: 883613.7177478	total: 603ms	remaining: 625ms
# 491:	learn: 883120.8859376	total: 604ms	remaining: 624ms
# 492:	learn: 882803.8559484	total: 605ms	remaining: 622ms
# 493:	learn: 882513.5237938	total: 606ms	remaining: 621ms
# 494:	learn: 882035.6829227	total: 607ms	remaining: 620ms
# 495:	learn: 881664.8868459	total: 608ms	remaining: 618ms
# 496:	learn: 881427.1195379	total: 609ms	remaining: 617ms
# 497:	learn: 880991.4197971	total: 611ms	remaining: 615ms
# 498:	learn: 880708.9226003	total: 612ms	remaining: 614ms
# 499:	learn: 880250.1384220	total: 613ms	remaining: 613ms
# 500:	learn: 879995.3546527	total: 614ms	remaining: 611ms
# 501:	learn: 879498.0603321	total: 615ms	remaining: 610ms
# 502:	learn: 879338.0541398	total: 616ms	remaining: 609ms
# 503:	learn: 878922.6654587	total: 617ms	remaining: 607ms
# 504:	learn: 878569.3572038	total: 618ms	remaining: 606ms
# 505:	learn: 878084.2642135	total: 619ms	remaining: 604ms
# 506:	learn: 877760.4130411	total: 620ms	remaining: 603ms
# 507:	learn: 877440.5454088	total: 621ms	remaining: 602ms
# 508:	learn: 877277.3917976	total: 622ms	remaining: 600ms
# 509:	learn: 876739.2370272	total: 623ms	remaining: 599ms
# 510:	learn: 876413.0962697	total: 624ms	remaining: 598ms
# 511:	learn: 876153.4334823	total: 626ms	remaining: 596ms
# 512:	learn: 875773.1094241	total: 627ms	remaining: 595ms
# 513:	learn: 875081.1888434	total: 628ms	remaining: 594ms
# 514:	learn: 874590.0460069	total: 629ms	remaining: 592ms
# 515:	learn: 874376.3695274	total: 630ms	remaining: 591ms
# 516:	learn: 874112.8269494	total: 631ms	remaining: 590ms
# 517:	learn: 873875.9201578	total: 632ms	remaining: 588ms
# 518:	learn: 873625.0548181	total: 633ms	remaining: 587ms
# 519:	learn: 873332.4519128	total: 634ms	remaining: 585ms
# 520:	learn: 873041.4643077	total: 635ms	remaining: 584ms
# 521:	learn: 872729.6522066	total: 636ms	remaining: 583ms
# 522:	learn: 872640.5581626	total: 637ms	remaining: 581ms
# 523:	learn: 872293.5634434	total: 638ms	remaining: 580ms
# 524:	learn: 872102.6332540	total: 640ms	remaining: 579ms
# 525:	learn: 871827.5973675	total: 641ms	remaining: 577ms
# 526:	learn: 871541.4549038	total: 642ms	remaining: 576ms
# 527:	learn: 871294.5771059	total: 643ms	remaining: 575ms
# 528:	learn: 870878.0938518	total: 644ms	remaining: 573ms
# 529:	learn: 870470.9584504	total: 645ms	remaining: 572ms
# 530:	learn: 870257.9962049	total: 646ms	remaining: 571ms
# 531:	learn: 869980.0981981	total: 647ms	remaining: 569ms
# 532:	learn: 869432.2199939	total: 648ms	remaining: 568ms
# 533:	learn: 869239.5270546	total: 649ms	remaining: 567ms
# 534:	learn: 868859.4812951	total: 650ms	remaining: 565ms
# 535:	learn: 868417.9279484	total: 651ms	remaining: 564ms
# 536:	learn: 867984.9618448	total: 653ms	remaining: 563ms
# 537:	learn: 867633.5537699	total: 654ms	remaining: 561ms
# 538:	learn: 867243.1003203	total: 655ms	remaining: 560ms
# 539:	learn: 866940.9209474	total: 656ms	remaining: 559ms
# 540:	learn: 866596.7592643	total: 657ms	remaining: 557ms
# 541:	learn: 866330.2793779	total: 658ms	remaining: 556ms
# 542:	learn: 866099.0571158	total: 659ms	remaining: 555ms
# 543:	learn: 865812.3049741	total: 660ms	remaining: 553ms
# 544:	learn: 865325.0633275	total: 661ms	remaining: 552ms
# 545:	learn: 865101.0204780	total: 662ms	remaining: 551ms
# 546:	learn: 864757.6306942	total: 663ms	remaining: 549ms
# 547:	learn: 864552.3535549	total: 664ms	remaining: 548ms
# 548:	learn: 864277.3951748	total: 665ms	remaining: 547ms
# 549:	learn: 863946.1013052	total: 667ms	remaining: 545ms
# 550:	learn: 863615.1194993	total: 668ms	remaining: 544ms
# 551:	learn: 863202.2277932	total: 669ms	remaining: 543ms
# 552:	learn: 862839.7234101	total: 670ms	remaining: 542ms
# 553:	learn: 862671.1802643	total: 671ms	remaining: 540ms
# 554:	learn: 862474.6318992	total: 672ms	remaining: 539ms
# 555:	learn: 862266.1567520	total: 673ms	remaining: 538ms
# 556:	learn: 861901.8409143	total: 674ms	remaining: 536ms
# 557:	learn: 861718.8859871	total: 675ms	remaining: 535ms
# 558:	learn: 861558.1700194	total: 676ms	remaining: 534ms
# 559:	learn: 861302.4552726	total: 678ms	remaining: 532ms
# 560:	learn: 861096.3463315	total: 679ms	remaining: 531ms
# 561:	learn: 860878.3898529	total: 680ms	remaining: 530ms
# 562:	learn: 860595.0380048	total: 681ms	remaining: 528ms
# 563:	learn: 860221.4631528	total: 682ms	remaining: 527ms
# 564:	learn: 859902.6514096	total: 683ms	remaining: 526ms
# 565:	learn: 859617.4517917	total: 684ms	remaining: 525ms
# 566:	learn: 859428.1472565	total: 685ms	remaining: 523ms
# 567:	learn: 859109.2812099	total: 686ms	remaining: 522ms
# 568:	learn: 858724.2999044	total: 687ms	remaining: 521ms
# 569:	learn: 858334.8802024	total: 688ms	remaining: 519ms
# 570:	learn: 858116.0603640	total: 689ms	remaining: 518ms
# 571:	learn: 857699.4315241	total: 691ms	remaining: 517ms
# 572:	learn: 857475.1863861	total: 692ms	remaining: 515ms
# 573:	learn: 857229.9304498	total: 693ms	remaining: 514ms
# 574:	learn: 856887.5072360	total: 694ms	remaining: 513ms
# 575:	learn: 856426.8836142	total: 695ms	remaining: 512ms
# 576:	learn: 856136.6242030	total: 696ms	remaining: 510ms
# 577:	learn: 855886.6891376	total: 697ms	remaining: 509ms
# 578:	learn: 855781.7162876	total: 698ms	remaining: 508ms
# 579:	learn: 855580.5978046	total: 699ms	remaining: 506ms
# 580:	learn: 855343.4356195	total: 700ms	remaining: 505ms
# 581:	learn: 854967.1306992	total: 701ms	remaining: 504ms
# 582:	learn: 854742.3417705	total: 703ms	remaining: 503ms
# 583:	learn: 854506.0977655	total: 704ms	remaining: 501ms
# 584:	learn: 854215.6881709	total: 705ms	remaining: 500ms
# 585:	learn: 853873.0975509	total: 706ms	remaining: 499ms
# 586:	learn: 853454.2233298	total: 707ms	remaining: 497ms
# 587:	learn: 853201.7262399	total: 708ms	remaining: 496ms
# 588:	learn: 852987.2590939	total: 709ms	remaining: 495ms
# 589:	learn: 852671.8667579	total: 710ms	remaining: 494ms
# 590:	learn: 852431.3071773	total: 711ms	remaining: 492ms
# 591:	learn: 851952.2995423	total: 713ms	remaining: 491ms
# 592:	learn: 851678.9140626	total: 714ms	remaining: 490ms
# 593:	learn: 851422.6316132	total: 715ms	remaining: 488ms
# 594:	learn: 851146.9210841	total: 716ms	remaining: 487ms
# 595:	learn: 850935.1853997	total: 717ms	remaining: 486ms
# 596:	learn: 850413.8497618	total: 718ms	remaining: 485ms
# 597:	learn: 850213.4837279	total: 719ms	remaining: 483ms
# 598:	learn: 849870.4840681	total: 720ms	remaining: 482ms
# 599:	learn: 849431.6237328	total: 721ms	remaining: 481ms
# 600:	learn: 849230.1308154	total: 722ms	remaining: 480ms
# 601:	learn: 848913.3157508	total: 723ms	remaining: 478ms
# 602:	learn: 848523.6191345	total: 724ms	remaining: 477ms
# 603:	learn: 848306.1262313	total: 726ms	remaining: 476ms
# 604:	learn: 848050.7286298	total: 727ms	remaining: 474ms
# 605:	learn: 847768.6690801	total: 728ms	remaining: 473ms
# 606:	learn: 847375.7339912	total: 729ms	remaining: 472ms
# 607:	learn: 847203.1634672	total: 730ms	remaining: 471ms
# 608:	learn: 846992.2421733	total: 731ms	remaining: 469ms
# 609:	learn: 846542.1445427	total: 732ms	remaining: 468ms
# 610:	learn: 846242.2117112	total: 733ms	remaining: 467ms
# 611:	learn: 845959.8906044	total: 734ms	remaining: 466ms
# 612:	learn: 845749.6085318	total: 735ms	remaining: 464ms
# 613:	learn: 845570.0899474	total: 736ms	remaining: 463ms
# 614:	learn: 845361.9549735	total: 738ms	remaining: 462ms
# 615:	learn: 845077.4347236	total: 739ms	remaining: 460ms
# 616:	learn: 844858.8913662	total: 740ms	remaining: 459ms
# 617:	learn: 844569.8589937	total: 741ms	remaining: 458ms
# 618:	learn: 844336.7833974	total: 742ms	remaining: 457ms
# 619:	learn: 843953.7309824	total: 743ms	remaining: 455ms
# 620:	learn: 843490.7044829	total: 744ms	remaining: 454ms
# 621:	learn: 843047.9073605	total: 745ms	remaining: 453ms
# 622:	learn: 842799.2037698	total: 746ms	remaining: 452ms
# 623:	learn: 842334.4990783	total: 747ms	remaining: 450ms
# 624:	learn: 841974.6855330	total: 749ms	remaining: 449ms
# 625:	learn: 841737.7624218	total: 750ms	remaining: 448ms
# 626:	learn: 841376.7092529	total: 751ms	remaining: 447ms
# 627:	learn: 841281.2432357	total: 752ms	remaining: 445ms
# 628:	learn: 841072.8202529	total: 753ms	remaining: 444ms
# 629:	learn: 840448.2033607	total: 754ms	remaining: 443ms
# 630:	learn: 840144.1650911	total: 755ms	remaining: 441ms
# 631:	learn: 839822.1481893	total: 756ms	remaining: 440ms
# 632:	learn: 839479.4197752	total: 757ms	remaining: 439ms
# 633:	learn: 839107.8777223	total: 758ms	remaining: 438ms
# 634:	learn: 838726.4854728	total: 759ms	remaining: 437ms
# 635:	learn: 838418.9921939	total: 761ms	remaining: 435ms
# 636:	learn: 838062.5158978	total: 762ms	remaining: 434ms
# 637:	learn: 837886.7621906	total: 763ms	remaining: 433ms
# 638:	learn: 837609.9913838	total: 765ms	remaining: 432ms
# 639:	learn: 837411.2094195	total: 766ms	remaining: 431ms
# 640:	learn: 837139.2447918	total: 767ms	remaining: 430ms
# 641:	learn: 836962.0942097	total: 768ms	remaining: 428ms
# 642:	learn: 836764.1536161	total: 769ms	remaining: 427ms
# 643:	learn: 836393.0539657	total: 771ms	remaining: 426ms
# 644:	learn: 836173.3759412	total: 772ms	remaining: 425ms
# 645:	learn: 835941.1882870	total: 773ms	remaining: 423ms
# 646:	learn: 835684.6514108	total: 774ms	remaining: 422ms
# 647:	learn: 835467.8102491	total: 775ms	remaining: 421ms
# 648:	learn: 835126.3976593	total: 776ms	remaining: 420ms
# 649:	learn: 834871.3252909	total: 778ms	remaining: 419ms
# 650:	learn: 834413.0570348	total: 780ms	remaining: 418ms
# 651:	learn: 834210.0551942	total: 781ms	remaining: 417ms
# 652:	learn: 833890.8556667	total: 782ms	remaining: 416ms
# 653:	learn: 833760.7610925	total: 783ms	remaining: 414ms
# 654:	learn: 833267.2287604	total: 784ms	remaining: 413ms
# 655:	learn: 832899.7056388	total: 786ms	remaining: 412ms
# 656:	learn: 832528.7299946	total: 787ms	remaining: 411ms
# 657:	learn: 832161.6910627	total: 788ms	remaining: 410ms
# 658:	learn: 831754.6838273	total: 789ms	remaining: 408ms
# 659:	learn: 831550.9203892	total: 790ms	remaining: 407ms
# 660:	learn: 831369.6000461	total: 792ms	remaining: 406ms
# 661:	learn: 831142.5498006	total: 793ms	remaining: 405ms
# 662:	learn: 830917.4072002	total: 794ms	remaining: 403ms
# 663:	learn: 830698.1576310	total: 795ms	remaining: 402ms
# 664:	learn: 830374.4281304	total: 796ms	remaining: 401ms
# 665:	learn: 830021.9643777	total: 797ms	remaining: 400ms
# 666:	learn: 829741.3042374	total: 798ms	remaining: 399ms
# 667:	learn: 829556.3955706	total: 799ms	remaining: 397ms
# 668:	learn: 829385.5011315	total: 800ms	remaining: 396ms
# 669:	learn: 829098.0038257	total: 802ms	remaining: 395ms
# 670:	learn: 828457.0358103	total: 803ms	remaining: 394ms
# 671:	learn: 828188.4260781	total: 804ms	remaining: 392ms
# 672:	learn: 827741.1312620	total: 805ms	remaining: 391ms
# 673:	learn: 827421.6867853	total: 806ms	remaining: 390ms
# 674:	learn: 827199.3310294	total: 807ms	remaining: 389ms
# 675:	learn: 826977.9205503	total: 809ms	remaining: 388ms
# 676:	learn: 826841.5643631	total: 810ms	remaining: 386ms
# 677:	learn: 826579.6395681	total: 811ms	remaining: 385ms
# 678:	learn: 826271.4179749	total: 813ms	remaining: 384ms
# 679:	learn: 825953.2097528	total: 814ms	remaining: 383ms
# 680:	learn: 825687.9391780	total: 815ms	remaining: 382ms
# 681:	learn: 825435.8708492	total: 816ms	remaining: 381ms
# 682:	learn: 825226.7404739	total: 817ms	remaining: 379ms
# 683:	learn: 824898.3669169	total: 818ms	remaining: 378ms
# 684:	learn: 824524.4624455	total: 820ms	remaining: 377ms
# 685:	learn: 824180.7146886	total: 821ms	remaining: 376ms
# 686:	learn: 823887.9000931	total: 822ms	remaining: 374ms
# 687:	learn: 823562.4987460	total: 823ms	remaining: 373ms
# 688:	learn: 823366.8940161	total: 824ms	remaining: 372ms
# 689:	learn: 823054.6909600	total: 825ms	remaining: 371ms
# 690:	learn: 822859.6386292	total: 827ms	remaining: 370ms
# 691:	learn: 822680.9019052	total: 828ms	remaining: 369ms
# 692:	learn: 822325.2591972	total: 830ms	remaining: 368ms
# 693:	learn: 822035.8797967	total: 831ms	remaining: 367ms
# 694:	learn: 821872.4337539	total: 833ms	remaining: 365ms
# 695:	learn: 821557.7631845	total: 834ms	remaining: 364ms
# 696:	learn: 821270.7179889	total: 835ms	remaining: 363ms
# 697:	learn: 821083.2300698	total: 836ms	remaining: 362ms
# 698:	learn: 820814.4860481	total: 837ms	remaining: 361ms
# 699:	learn: 820617.6068276	total: 839ms	remaining: 359ms
# 700:	learn: 820276.1255613	total: 840ms	remaining: 358ms
# 701:	learn: 819994.2771324	total: 841ms	remaining: 357ms
# 702:	learn: 819728.1964452	total: 842ms	remaining: 356ms
# 703:	learn: 819343.1630071	total: 843ms	remaining: 355ms
# 704:	learn: 819046.2340070	total: 845ms	remaining: 354ms
# 705:	learn: 818510.4391753	total: 846ms	remaining: 352ms
# 706:	learn: 818265.7326538	total: 848ms	remaining: 351ms
# 707:	learn: 818171.0156518	total: 849ms	remaining: 350ms
# 708:	learn: 817942.5811453	total: 850ms	remaining: 349ms
# 709:	learn: 817805.0998962	total: 851ms	remaining: 348ms
# 710:	learn: 817540.0012405	total: 852ms	remaining: 346ms
# 711:	learn: 817291.2600966	total: 853ms	remaining: 345ms
# 712:	learn: 817144.5042017	total: 855ms	remaining: 344ms
# 713:	learn: 816880.4812866	total: 856ms	remaining: 343ms
# 714:	learn: 816465.4416735	total: 857ms	remaining: 342ms
# 715:	learn: 816276.6177884	total: 858ms	remaining: 340ms
# 716:	learn: 816063.0811215	total: 859ms	remaining: 339ms
# 717:	learn: 815902.1067414	total: 860ms	remaining: 338ms
# 718:	learn: 815563.9571632	total: 861ms	remaining: 337ms
# 719:	learn: 815274.3092388	total: 863ms	remaining: 335ms
# 720:	learn: 815090.2725514	total: 864ms	remaining: 334ms
# 721:	learn: 814903.3789244	total: 865ms	remaining: 333ms
# 722:	learn: 814648.6316642	total: 866ms	remaining: 332ms
# 723:	learn: 814431.4527359	total: 868ms	remaining: 331ms
# 724:	learn: 814227.6957409	total: 869ms	remaining: 330ms
# 725:	learn: 813985.2345534	total: 870ms	remaining: 328ms
# 726:	learn: 813755.8469684	total: 871ms	remaining: 327ms
# 727:	learn: 813476.4892840	total: 872ms	remaining: 326ms
# 728:	learn: 813193.7358646	total: 873ms	remaining: 325ms
# 729:	learn: 812885.2071431	total: 874ms	remaining: 323ms
# 730:	learn: 812308.1415360	total: 876ms	remaining: 322ms
# 731:	learn: 811947.6016913	total: 877ms	remaining: 321ms
# 732:	learn: 811506.4460136	total: 878ms	remaining: 320ms
# 733:	learn: 811254.6970565	total: 879ms	remaining: 319ms
# 734:	learn: 810918.4136582	total: 881ms	remaining: 318ms
# 735:	learn: 810673.8034809	total: 882ms	remaining: 316ms
# 736:	learn: 810517.8252836	total: 883ms	remaining: 315ms
# 737:	learn: 810274.8577220	total: 885ms	remaining: 314ms
# 738:	learn: 810108.2022742	total: 886ms	remaining: 313ms
# 739:	learn: 809935.7555105	total: 887ms	remaining: 312ms
# 740:	learn: 809632.7601702	total: 888ms	remaining: 311ms
# 741:	learn: 809399.8070089	total: 891ms	remaining: 310ms
# 742:	learn: 809177.2207194	total: 892ms	remaining: 309ms
# 743:	learn: 808857.9367822	total: 893ms	remaining: 307ms
# 744:	learn: 808596.4054952	total: 894ms	remaining: 306ms
# 745:	learn: 808270.4908612	total: 896ms	remaining: 305ms
# 746:	learn: 808135.9591060	total: 897ms	remaining: 304ms
# 747:	learn: 807795.9270992	total: 898ms	remaining: 303ms
# 748:	learn: 807435.7833090	total: 900ms	remaining: 302ms
# 749:	learn: 807251.5629177	total: 901ms	remaining: 300ms
# 750:	learn: 806972.2281936	total: 902ms	remaining: 299ms
# 751:	learn: 806564.6125407	total: 904ms	remaining: 298ms
# 752:	learn: 806228.3977038	total: 905ms	remaining: 297ms
# 753:	learn: 806094.2728322	total: 906ms	remaining: 296ms
# 754:	learn: 805612.7669323	total: 908ms	remaining: 295ms
# 755:	learn: 805316.7059576	total: 909ms	remaining: 293ms
# 756:	learn: 805139.5700543	total: 910ms	remaining: 292ms
# 757:	learn: 804900.5951090	total: 912ms	remaining: 291ms
# 758:	learn: 804722.0979474	total: 913ms	remaining: 290ms
# 759:	learn: 804455.5352411	total: 915ms	remaining: 289ms
# 760:	learn: 804209.4442163	total: 916ms	remaining: 288ms
# 761:	learn: 803851.6690880	total: 917ms	remaining: 286ms
# 762:	learn: 803469.0683112	total: 919ms	remaining: 285ms
# 763:	learn: 803348.7903177	total: 920ms	remaining: 284ms
# 764:	learn: 803169.8353339	total: 921ms	remaining: 283ms
# 765:	learn: 803064.4823614	total: 922ms	remaining: 282ms
# 766:	learn: 802919.1827310	total: 923ms	remaining: 280ms
# 767:	learn: 802701.5750391	total: 924ms	remaining: 279ms
# 768:	learn: 802613.0982568	total: 926ms	remaining: 278ms
# 769:	learn: 802417.6297946	total: 927ms	remaining: 277ms
# 770:	learn: 802189.0614499	total: 928ms	remaining: 276ms
# 771:	learn: 801936.0792699	total: 929ms	remaining: 274ms
# 772:	learn: 801781.9482953	total: 930ms	remaining: 273ms
# 773:	learn: 801631.0245612	total: 931ms	remaining: 272ms
# 774:	learn: 801524.0668955	total: 932ms	remaining: 271ms
# 775:	learn: 801362.7698605	total: 934ms	remaining: 270ms
# 776:	learn: 801180.4094990	total: 935ms	remaining: 268ms
# 777:	learn: 801119.4173193	total: 936ms	remaining: 267ms
# 778:	learn: 800879.3637030	total: 937ms	remaining: 266ms
# 779:	learn: 800752.5451808	total: 939ms	remaining: 265ms
# 780:	learn: 800420.7532566	total: 940ms	remaining: 263ms
# 781:	learn: 800141.7532420	total: 941ms	remaining: 262ms
# 782:	learn: 799931.8435649	total: 942ms	remaining: 261ms
# 783:	learn: 799809.4117606	total: 943ms	remaining: 260ms
# 784:	learn: 799665.1394440	total: 944ms	remaining: 259ms
# 785:	learn: 799420.6321391	total: 946ms	remaining: 257ms
# 786:	learn: 799256.7344107	total: 947ms	remaining: 256ms
# 787:	learn: 798976.1997113	total: 948ms	remaining: 255ms
# 788:	learn: 798942.4418613	total: 949ms	remaining: 254ms
# 789:	learn: 798552.4344931	total: 950ms	remaining: 253ms
# 790:	learn: 798295.0791448	total: 951ms	remaining: 251ms
# 791:	learn: 797791.6707372	total: 953ms	remaining: 250ms
# 792:	learn: 797636.6239395	total: 954ms	remaining: 249ms
# 793:	learn: 797524.3635643	total: 955ms	remaining: 248ms
# 794:	learn: 797364.5195684	total: 956ms	remaining: 247ms
# 795:	learn: 797116.1430022	total: 957ms	remaining: 245ms
# 796:	learn: 796843.1755177	total: 958ms	remaining: 244ms
# 797:	learn: 796517.3461669	total: 960ms	remaining: 243ms
# 798:	learn: 796337.5066144	total: 961ms	remaining: 242ms
# 799:	learn: 796027.0708418	total: 963ms	remaining: 241ms
# 800:	learn: 795944.2389555	total: 964ms	remaining: 240ms
# 801:	learn: 795699.4630190	total: 965ms	remaining: 238ms
# 802:	learn: 795521.8327885	total: 967ms	remaining: 237ms
# 803:	learn: 795133.1654785	total: 968ms	remaining: 236ms
# 804:	learn: 794950.7310963	total: 969ms	remaining: 235ms
# 805:	learn: 794707.6388674	total: 970ms	remaining: 234ms
# 806:	learn: 794383.1338798	total: 971ms	remaining: 232ms
# 807:	learn: 794265.3730883	total: 973ms	remaining: 231ms
# 808:	learn: 794041.3894523	total: 974ms	remaining: 230ms
# 809:	learn: 793885.9464417	total: 975ms	remaining: 229ms
# 810:	learn: 793702.5398635	total: 976ms	remaining: 228ms
# 811:	learn: 793187.0147640	total: 978ms	remaining: 226ms
# 812:	learn: 792876.2064238	total: 979ms	remaining: 225ms
# 813:	learn: 792571.0958465	total: 980ms	remaining: 224ms
# 814:	learn: 792394.2026721	total: 981ms	remaining: 223ms
# 815:	learn: 792275.7353863	total: 983ms	remaining: 222ms
# 816:	learn: 792018.5953022	total: 984ms	remaining: 220ms
# 817:	learn: 791720.8628956	total: 985ms	remaining: 219ms
# 818:	learn: 791514.6828074	total: 986ms	remaining: 218ms
# 819:	learn: 791177.3454547	total: 988ms	remaining: 217ms
# 820:	learn: 790998.9412413	total: 990ms	remaining: 216ms
# 821:	learn: 790670.6601963	total: 991ms	remaining: 215ms
# 822:	learn: 790571.0142611	total: 992ms	remaining: 213ms
# 823:	learn: 790412.7740361	total: 993ms	remaining: 212ms
# 824:	learn: 790202.5777899	total: 995ms	remaining: 211ms
# 825:	learn: 789953.0967455	total: 996ms	remaining: 210ms
# 826:	learn: 789779.1953592	total: 997ms	remaining: 209ms
# 827:	learn: 789698.5948523	total: 998ms	remaining: 207ms
# 828:	learn: 789543.8393501	total: 1000ms	remaining: 206ms
# 829:	learn: 789379.6180672	total: 1s	remaining: 205ms
# 830:	learn: 789179.1277322	total: 1s	remaining: 204ms
# 831:	learn: 788919.0748202	total: 1s	remaining: 203ms
# 832:	learn: 788679.5333268	total: 1s	remaining: 202ms
# 833:	learn: 788402.0024869	total: 1.01s	remaining: 200ms
# 834:	learn: 788082.3092519	total: 1.01s	remaining: 199ms
# 835:	learn: 787975.2569900	total: 1.01s	remaining: 198ms
# 836:	learn: 787821.3895967	total: 1.01s	remaining: 197ms
# 837:	learn: 787457.2948799	total: 1.01s	remaining: 195ms
# 838:	learn: 787206.2926883	total: 1.01s	remaining: 194ms
# 839:	learn: 787048.6196732	total: 1.01s	remaining: 193ms
# 840:	learn: 786878.1401933	total: 1.01s	remaining: 192ms
# 841:	learn: 786640.2892579	total: 1.02s	remaining: 191ms
# 842:	learn: 786395.3386958	total: 1.02s	remaining: 190ms
# 843:	learn: 786138.2364746	total: 1.02s	remaining: 189ms
# 844:	learn: 785921.4679515	total: 1.02s	remaining: 187ms
# 845:	learn: 785771.0541100	total: 1.02s	remaining: 186ms
# 846:	learn: 785502.8211341	total: 1.02s	remaining: 185ms
# 847:	learn: 785305.9835911	total: 1.02s	remaining: 184ms
# 848:	learn: 785082.8273714	total: 1.03s	remaining: 183ms
# 849:	learn: 784831.9344110	total: 1.03s	remaining: 181ms
# 850:	learn: 784767.0986599	total: 1.03s	remaining: 180ms
# 851:	learn: 784620.9170378	total: 1.03s	remaining: 179ms
# 852:	learn: 784559.0905634	total: 1.03s	remaining: 178ms
# 853:	learn: 784320.8652167	total: 1.03s	remaining: 176ms
# 854:	learn: 784277.3085362	total: 1.03s	remaining: 175ms
# 855:	learn: 783839.8544464	total: 1.03s	remaining: 174ms
# 856:	learn: 783365.1673691	total: 1.03s	remaining: 173ms
# 857:	learn: 783146.2661517	total: 1.04s	remaining: 172ms
# 858:	learn: 782630.3079092	total: 1.04s	remaining: 170ms
# 859:	learn: 782336.0351956	total: 1.04s	remaining: 169ms
# 860:	learn: 782205.2154743	total: 1.04s	remaining: 168ms
# 861:	learn: 782064.3816844	total: 1.04s	remaining: 167ms
# 862:	learn: 781888.9700234	total: 1.04s	remaining: 166ms
# 863:	learn: 781660.6376110	total: 1.04s	remaining: 164ms
# 864:	learn: 781461.4099223	total: 1.04s	remaining: 163ms
# 865:	learn: 781240.8162817	total: 1.05s	remaining: 162ms
# 866:	learn: 780897.8437495	total: 1.05s	remaining: 161ms
# 867:	learn: 780316.2488582	total: 1.05s	remaining: 160ms
# 868:	learn: 780109.6584044	total: 1.05s	remaining: 158ms
# 869:	learn: 779852.9767841	total: 1.05s	remaining: 157ms
# 870:	learn: 779646.8929622	total: 1.05s	remaining: 156ms
# 871:	learn: 779343.6672859	total: 1.05s	remaining: 155ms
# 872:	learn: 779305.9761849	total: 1.05s	remaining: 153ms
# 873:	learn: 779024.3051697	total: 1.06s	remaining: 152ms
# 874:	learn: 778880.1122036	total: 1.06s	remaining: 151ms
# 875:	learn: 778667.1006137	total: 1.06s	remaining: 150ms
# 876:	learn: 778395.3713743	total: 1.06s	remaining: 149ms
# 877:	learn: 778167.1540316	total: 1.06s	remaining: 147ms
# 878:	learn: 777974.7166712	total: 1.06s	remaining: 146ms
# 879:	learn: 777783.8329654	total: 1.06s	remaining: 145ms
# 880:	learn: 777667.3957837	total: 1.06s	remaining: 144ms
# 881:	learn: 777503.5664437	total: 1.06s	remaining: 143ms
# 882:	learn: 777133.8919038	total: 1.07s	remaining: 141ms
# 883:	learn: 776928.7169691	total: 1.07s	remaining: 140ms
# 884:	learn: 776732.2199936	total: 1.07s	remaining: 139ms
# 885:	learn: 776578.5206906	total: 1.07s	remaining: 138ms
# 886:	learn: 776331.3891007	total: 1.07s	remaining: 137ms
# 887:	learn: 776121.3630730	total: 1.07s	remaining: 135ms
# 888:	learn: 775854.0277706	total: 1.07s	remaining: 134ms
# 889:	learn: 775779.9488875	total: 1.07s	remaining: 133ms
# 890:	learn: 775659.8665843	total: 1.08s	remaining: 132ms
# 891:	learn: 775555.4130769	total: 1.08s	remaining: 131ms
# 892:	learn: 775497.0107590	total: 1.08s	remaining: 129ms
# 893:	learn: 775226.5500589	total: 1.08s	remaining: 128ms
# 894:	learn: 775054.0263728	total: 1.08s	remaining: 127ms
# 895:	learn: 774923.6524284	total: 1.08s	remaining: 126ms
# 896:	learn: 774594.9957884	total: 1.08s	remaining: 124ms
# 897:	learn: 774257.4648168	total: 1.08s	remaining: 123ms
# 898:	learn: 773945.6511205	total: 1.08s	remaining: 122ms
# 899:	learn: 773626.6047763	total: 1.09s	remaining: 121ms
# 900:	learn: 773463.6204415	total: 1.09s	remaining: 120ms
# 901:	learn: 773123.5679242	total: 1.09s	remaining: 118ms
# 902:	learn: 773088.5709559	total: 1.09s	remaining: 117ms
# 903:	learn: 772830.8390505	total: 1.09s	remaining: 116ms
# 904:	learn: 772682.9481737	total: 1.09s	remaining: 115ms
# 905:	learn: 772523.1482851	total: 1.09s	remaining: 114ms
# 906:	learn: 772366.1391235	total: 1.09s	remaining: 112ms
# 907:	learn: 772163.3372717	total: 1.1s	remaining: 111ms
# 908:	learn: 772004.6528948	total: 1.1s	remaining: 110ms
# 909:	learn: 771810.2821894	total: 1.1s	remaining: 109ms
# 910:	learn: 771640.7189389	total: 1.1s	remaining: 107ms
# 911:	learn: 771467.2114984	total: 1.1s	remaining: 106ms
# 912:	learn: 771293.6226791	total: 1.1s	remaining: 105ms
# 913:	learn: 771152.5206990	total: 1.1s	remaining: 104ms
# 914:	learn: 770958.6615120	total: 1.1s	remaining: 103ms
# 915:	learn: 770750.1330418	total: 1.1s	remaining: 101ms
# 916:	learn: 770690.5222418	total: 1.11s	remaining: 100ms
# 917:	learn: 770395.2662260	total: 1.11s	remaining: 98.9ms
# 918:	learn: 770131.6866505	total: 1.11s	remaining: 97.7ms
# 919:	learn: 769905.6080917	total: 1.11s	remaining: 96.6ms
# 920:	learn: 769652.5284617	total: 1.11s	remaining: 95.4ms
# 921:	learn: 769399.4878554	total: 1.11s	remaining: 94.2ms
# 922:	learn: 769186.2750130	total: 1.11s	remaining: 93ms
# 923:	learn: 769033.5382297	total: 1.12s	remaining: 91.8ms
# 924:	learn: 768832.6905130	total: 1.12s	remaining: 90.6ms
# 925:	learn: 768598.6234251	total: 1.12s	remaining: 89.5ms
# 926:	learn: 768376.7891102	total: 1.12s	remaining: 88.3ms
# 927:	learn: 768137.4824769	total: 1.12s	remaining: 87.1ms
# 928:	learn: 767855.6030433	total: 1.12s	remaining: 85.9ms
# 929:	learn: 767591.7396172	total: 1.12s	remaining: 84.7ms
# 930:	learn: 767316.4565718	total: 1.13s	remaining: 83.5ms
# 931:	learn: 767165.2302640	total: 1.13s	remaining: 82.2ms
# 932:	learn: 767018.7644302	total: 1.13s	remaining: 81ms
# 933:	learn: 766577.1324161	total: 1.13s	remaining: 79.8ms
# 934:	learn: 766363.0824098	total: 1.13s	remaining: 78.6ms
# 935:	learn: 766185.6003873	total: 1.13s	remaining: 77.4ms
# 936:	learn: 766086.6944904	total: 1.13s	remaining: 76.2ms
# 937:	learn: 765947.3495291	total: 1.13s	remaining: 75ms
# 938:	learn: 765746.6556965	total: 1.14s	remaining: 73.8ms
# 939:	learn: 765464.5418447	total: 1.14s	remaining: 72.6ms
# 940:	learn: 765257.0598402	total: 1.14s	remaining: 71.4ms
# 941:	learn: 764846.5329479	total: 1.14s	remaining: 70.2ms
# 942:	learn: 764694.8619237	total: 1.14s	remaining: 69ms
# 943:	learn: 764528.9914990	total: 1.14s	remaining: 67.7ms
# 944:	learn: 764384.5997613	total: 1.14s	remaining: 66.5ms
# 945:	learn: 764135.4210523	total: 1.14s	remaining: 65.3ms
# 946:	learn: 764049.3003118	total: 1.15s	remaining: 64.1ms
# 947:	learn: 763832.7845329	total: 1.15s	remaining: 62.9ms
# 948:	learn: 763538.0776883	total: 1.15s	remaining: 61.7ms
# 949:	learn: 763333.5473993	total: 1.15s	remaining: 60.5ms
# 950:	learn: 763052.7130656	total: 1.15s	remaining: 59.3ms
# 951:	learn: 762745.7776487	total: 1.15s	remaining: 58.1ms
# 952:	learn: 762575.0765918	total: 1.15s	remaining: 56.9ms
# 953:	learn: 762453.2069158	total: 1.15s	remaining: 55.7ms
# 954:	learn: 762261.1440209	total: 1.16s	remaining: 54.5ms
# 955:	learn: 762094.9848047	total: 1.16s	remaining: 53.3ms
# 956:	learn: 761866.2086643	total: 1.16s	remaining: 52ms
# 957:	learn: 761663.3986989	total: 1.16s	remaining: 50.8ms
# 958:	learn: 761407.1781112	total: 1.16s	remaining: 49.6ms
# 959:	learn: 761272.7428516	total: 1.16s	remaining: 48.4ms
# 960:	learn: 761093.7449160	total: 1.16s	remaining: 47.2ms
# 961:	learn: 760893.1485175	total: 1.16s	remaining: 46ms
# 962:	learn: 760660.2959759	total: 1.17s	remaining: 44.8ms
# 963:	learn: 760360.2042523	total: 1.17s	remaining: 43.6ms
# 964:	learn: 760170.7079960	total: 1.17s	remaining: 42.4ms
# 965:	learn: 760110.5706403	total: 1.17s	remaining: 41.1ms
# 966:	learn: 759901.9221637	total: 1.17s	remaining: 39.9ms
# 967:	learn: 759780.4717185	total: 1.17s	remaining: 38.7ms
# 968:	learn: 759551.5136581	total: 1.17s	remaining: 37.5ms
# 969:	learn: 759348.7682867	total: 1.17s	remaining: 36.3ms
# 970:	learn: 759107.7111513	total: 1.18s	remaining: 35.1ms
# 971:	learn: 758909.6481342	total: 1.18s	remaining: 33.9ms
# 972:	learn: 758621.3535498	total: 1.18s	remaining: 32.7ms
# 973:	learn: 758394.9553280	total: 1.18s	remaining: 31.5ms
# 974:	learn: 758238.0686091	total: 1.18s	remaining: 30.3ms
# 975:	learn: 758053.9951079	total: 1.18s	remaining: 29.1ms
# 976:	learn: 757833.3723607	total: 1.18s	remaining: 27.8ms
# 977:	learn: 757564.9156549	total: 1.18s	remaining: 26.6ms
# 978:	learn: 757424.6682650	total: 1.18s	remaining: 25.4ms
# 979:	learn: 757173.4587572	total: 1.19s	remaining: 24.2ms
# 980:	learn: 757139.8529807	total: 1.19s	remaining: 23ms
# 981:	learn: 757010.4183730	total: 1.19s	remaining: 21.8ms
# 982:	learn: 756806.4957548	total: 1.19s	remaining: 20.6ms
# 983:	learn: 756627.3607165	total: 1.19s	remaining: 19.4ms
# 984:	learn: 756280.0948895	total: 1.19s	remaining: 18.2ms
# 985:	learn: 756252.5618915	total: 1.19s	remaining: 16.9ms
# 986:	learn: 755975.5054724	total: 1.19s	remaining: 15.7ms
# 987:	learn: 755738.9589908	total: 1.2s	remaining: 14.5ms
# 988:	learn: 755639.8698029	total: 1.2s	remaining: 13.3ms
# 989:	learn: 755488.6168456	total: 1.2s	remaining: 12.1ms
# 990:	learn: 755292.1687095	total: 1.2s	remaining: 10.9ms
# 991:	learn: 755188.1972467	total: 1.2s	remaining: 9.68ms
# 992:	learn: 755083.6294217	total: 1.2s	remaining: 8.47ms
# 993:	learn: 754883.6532148	total: 1.2s	remaining: 7.26ms
# 994:	learn: 754797.0287514	total: 1.2s	remaining: 6.05ms
# 995:	learn: 754512.1232134	total: 1.21s	remaining: 4.84ms
# 996:	learn: 754420.8873894	total: 1.21s	remaining: 3.63ms
# 997:	learn: 754218.3385755	total: 1.21s	remaining: 2.42ms
# 998:	learn: 753965.6180809	total: 1.21s	remaining: 1.21ms
# 999:	learn: 753802.9774938	total: 1.21s	remaining: 0us
# 0.8172266309213451

# %% [markdown]
# ### Model 4 - Result

# %%
# เทียบระหว่าง y_test กับ y_predict
# Mean Absolute Error (MAE)
mae_test = mean_absolute_error(Y_test, preds_cb)
print("Mean absolute error: %.3f" % mae_test)
# Mean Square Error
mse_test=mean_squared_error(Y_test, preds_cb)
print("Mean squared error: %.3f" % mse_test)

# R2-score: Explained variance (coefficient of determination) score: 1 is perfect prediction

r2_test= r2_score(Y_test, preds_cb)
print('R2-score: %.3f' % r2_test)
# Out:
# Mean absolute error: 660939.046
# Mean squared error: 874644393411.685
# R2-score: 0.817

# %%
import matplotlib
colors = np.random.randint(100, size=(100))
plt.scatter(Y_test, preds_cb,s=3,color = 'black')
plt.xlabel('True Values')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %% [markdown]
# ## Model 5 - Lasso

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)

# %%
lasso = Lasso(alpha=1.0)
lasso = lasso.fit(X_train_scaled, Y_train)
# Out:
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.137e+15, tolerance: 5.415e+12
#   model = cd_fast.enet_coordinate_descent(

# %%
print("LR.coef_: \n {}".format(lasso.coef_))
print("LR.intercept_: {}".format(lasso.intercept_))
# Out:
# LR.coef_:
#  [-209642.72878929  367610.8380539   742098.51099256  624778.30914803
#   347813.13376761  -15667.8512914   249046.30333804  344461.23293657
#  -230178.25748527  -16333.63382475       0.          802090.00610298
#    -9384.01807497    7451.59692421  -21272.0475581  -101907.17788642
#  -161709.3531465  -164426.52770122 -151838.60331463 -186715.13348962
#    47229.16153734 -168603.97895847   22197.20574648  -93750.42317831
#   -91158.92160699  -27173.77210639  254350.16564726  -42086.9953874
#   -93973.14064388  -87844.16582076  -70208.36650634  -33795.84219268
#  -179700.81422132  -13525.73619838 -137221.17470645    1138.23532369
#  -128742.67822952  -18392.56176027 -127477.86352645 -271698.22195861
#    33576.40505223  306617.86344124  -67864.07493755 -149709.89612983
#   -84554.51113657 -148718.40836924   32232.60482434  -22174.26682829
#  -142668.6007015  -108802.32192622   36589.74158048  198411.41681105
#  -125906.29805487   90441.32411062   16423.79272824   25040.8751496
#   -79232.53741052 -147079.39490908  -78280.46909326  213242.54166929
#  -166859.07545377  -66275.22620602 -112013.88859603  147122.67068725
#  -117469.75239156  -84713.39782481  -36590.68083057 -143095.26077988
#  -163478.1458937  -102172.67573458  346215.4436502   -21410.05593697
#   -32389.83066243  325459.796051   -219819.95376784]
# LR.intercept_: 4040143.1693237564

# %%
X_test_scaled = scaler.transform(X_test)
y_predict_ls = lasso.predict(X_test_scaled)

# %% [markdown]
# ### Model 5 - Result

# %%
# Mean Absolute Error (MAE)
mae_test = mean_absolute_error(Y_test, y_predict_ls)
print("Mean absolute error: %.3f" % mae_test)

# The mean squared error
mse_test=mean_squared_error(Y_test, y_predict_ls)
print("Mean squared error: %.3f" % mse_test)

# R2-score: Explained variance score: 1 is perfect prediction
r2_test= r2_score(Y_test, y_predict_ls)
print('R2-score: %f' % r2_test)
# Out:
# Mean absolute error: 948665.123
# Mean squared error: 1606639836338.242
# R2-score: 0.664262

# %%
from yellowbrick.datasets import load_concrete
from yellowbrick.regressor import PredictionError
from yellowbrick.style import set_palette

set_palette('accent')
model = Lasso(alpha=1.0)
visualizer = PredictionError(model)

visualizer.fit(X_train, Y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, Y_test)  # Evaluate the model on the test data
visualizer.show()
# Out:
# /Users/meepoom/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.989e+15, tolerance: 5.415e+12
#   model = cd_fast.enet_coordinate_descent(
# <Axes: title={'center': 'Prediction Error for Lasso'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
from yellowbrick.datasets import load_concrete
from yellowbrick.regressor import ResidualsPlot

model = Ridge()
visualizer = ResidualsPlot(model)

visualizer = ResidualsPlot(model)
visualizer.fit(X_train, Y_train)
visualizer.score(X_test, Y_test)
visualizer.show()
# Out:
# <Axes: title={'center': 'Residuals for Ridge Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# ## Model 6 - Ridge

# %%
RR = Ridge(alpha=100.0)
RR = RR.fit(X_train, Y_train)
y_predict = RR.predict(X_test)

# %%
Ridge()
# Out:
# Ridge()

# %%
RR.get_params()
# Out:
# {'alpha': 100.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': None,
#  'positive': False,
#  'random_state': None,
#  'solver': 'auto',
#  'tol': 0.0001}

# %%
# show model parameters
print("RR.coef_: \n {}".format(RR.coef_))
print("RR.intercept_: {}".format(RR.intercept_))
# Out:
# RR.coef_:
#  [-5.87681709e+02  3.32615451e+05  8.18009257e+05  9.59634170e+03
#   5.08167409e+04  1.66306529e+04  5.82273429e+04  8.30396654e+04
#  -1.32183152e+03 -5.48370121e+04  0.00000000e+00  5.95616833e+05
#  -3.35530056e+05 -2.60086777e+05 -2.33824450e+04 -2.76607391e+05
#  -4.51060697e+05 -4.74172051e+05 -4.22736818e+05 -4.55706545e+05
#   3.80509405e+05 -5.33613160e+05  3.09078991e+05 -3.99996952e+04
#  -3.19510832e+05  8.60877712e+04  1.36487040e+06 -7.73489322e+04
#  -1.29316343e+04 -3.13671094e+05 -2.23563789e+05  2.08733059e+04
#  -5.29987347e+05  3.11329921e+05 -3.75526657e+05  1.99508377e+05
#  -2.72344863e+05  1.77711860e+05 -3.37638229e+05 -6.36587007e+05
#   2.89751095e+05  1.33527901e+06 -1.10815596e+05 -3.73410333e+05
#  -4.06374272e+04 -3.66166798e+05  8.28718836e+04 -1.47182330e+05
#  -3.82250528e+05 -2.46296843e+05  2.57535414e+05  1.13550590e+06
#  -2.68959577e+05  5.94916881e+05  4.49316137e+05  1.53238957e+05
#  -2.51499798e+05 -2.08755837e+05 -2.11066264e+05  1.08425007e+06
#  -2.74739844e+05 -2.20284555e+05 -1.91630991e+05  8.92274389e+05
#  -1.32767028e+05 -2.00927896e+05 -1.41745268e+04 -5.78501409e+05
#  -4.89406005e+05 -2.53501332e+05  1.41819046e+06  1.96263876e+05
#   9.14539908e+04  6.31518334e+05 -7.22972325e+05]
# RR.intercept_: 178348.8501442452

# %%
print("Training set score: {:.3f}".format(RR.score(X_train, Y_train)))
print("Test set score: {:f}".format(RR.score(X_test, Y_test)))
# Out:
# Training set score: 0.626
# Test set score: 0.637050

# %% [markdown]
# ### Model 6 - Result

# %%
# Mean Absolute Error (MAE)
mae_test = mean_absolute_error(Y_test, y_predict)
print("Mean absolute error: %.3f" % mae_test)

# The mean squared error
mse_test=mean_squared_error(Y_test, y_predict)
print("Mean squared error: %.3f" % mse_test)

# R2-score: Explained variance score: 1 is perfect prediction
r2_test= r2_score(Y_test, y_predict)
print('R2-score: %f' % r2_test)
# Out:
# Mean absolute error: 999230.650
# Mean squared error: 1736860192563.077
# R2-score: 0.637050

# %%
from yellowbrick.datasets import load_concrete
from yellowbrick.regressor import PredictionError
from yellowbrick.style import set_palette

set_palette('accent')
model = Ridge(alpha=100.0)
visualizer = PredictionError(model)

visualizer.fit(X_train, Y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, Y_test)  # Evaluate the model on the test data
visualizer.show()
# Out:
# <Axes: title={'center': 'Prediction Error for Ridge'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
from yellowbrick.datasets import load_concrete
from yellowbrick.regressor import ResidualsPlot

model = Ridge(alpha=10.0)
visualizer = ResidualsPlot(model)

visualizer = ResidualsPlot(model)
visualizer.fit(X_train, Y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, Y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
# Out:
# <Axes: title={'center': 'Residuals for Ridge Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# In based on data that is the area and type of accommodation, Model Lasso and Ridge give a similar output of 0.664 - 0.663. It is therefore concluded that the location of the accommodation affects the valuation.
